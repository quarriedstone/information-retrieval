# %% [markdown]
# In this lab you are going to implement a standard document processing pipeline and then build a simple search engine based on it:
# - starting from crawling documents,
# - then building an inverted index,
# - answering queries using this index,
# - and organizing it as a simple web server.
#
# Second part is devoted to spellchecking.
#
# # 1. [45] Building inverted index and answering queries
#
# ## 1.1. [5] Preprocessing
#
# First, we need a unified approach to documents preprocessing. Implement a class responsible for that. Complete the code for given functions (most of them are just one-liners) and make sure you pass the tests. Make use of `nltk` library or any other you know.

# %%
import nltk
nltk.download('punkt')

class Preprocessor:
    
    def __init__(self):
        self.stop_words = {'a', 'an', 'and', 'are', 'as', 'at', 'be', 'by', 'for', 'from', 'has', 'he', 'in', 'is', 'it', 'its',
                      'of', 'on', 'that', 'the', 'to', 'was', 'were', 'will', 'with'}
        self.ps = nltk.stem.PorterStemmer()

    
    def tokenize(self, text):
        #TODO word tokenize text using nltk lib
        return nltk.word_tokenize(text)

    
    def stem(self, word, stemmer):
        #TODO stem word using provided stemmer
        return stemmer.stem(word)

    
    def is_apt_word(self, word):
        #TODO check if word is appropriate - not a stop word and isalpha, 
        # i.e consists of letters, not punctuation, numbers, dates
        return word not in self.stop_words and str.isalpha(word)

    
    def preprocess(self, text):
        #TODO combine all previous methods together: tokenize lowercased text 
        # and stem it, ignoring not appropriate words
        return [self.stem(word, self.ps) 
         for word in self.tokenize(text.lower())
         if self.is_apt_word(word)]
# Out:
# [nltk_data] Downloading package punkt to /Users/osmiyg/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### 1.1.1. Tests

# %%
prep = Preprocessor()
text = 'To be, or not to be, that is the question'

assert prep.tokenize(text) == ['To', 'be', ',', 'or', 'not', 'to', 'be', ',', 'that', 'is', 'the', 'question']
assert prep.stem('retrieval', prep.ps) == 'retriev'
assert prep.is_apt_word('qwerty123') is False
assert prep.preprocess(text) == ['or', 'not', 'question']

# %% [markdown]
# ## 1.2. [25] Crawling and Indexing
#
# ### 1.2.1. [5] Base classes
#
# Here are some base classes we will need for writing our indexer. The code from the first lab's solution is given, but note that you will need to change some of it, namely, the `parse` function (it is also possible to use your own implementation from the first homework, but make sure that it is correct). The reason is it always makes complete parsing, which we want to avoid when we only need links, for example, or a specific portion of text.

# %%
import requests
from urllib.parse import quote
from bs4 import BeautifulSoup
from bs4.element import Comment
import urllib.parse
from pathlib import Path
import os


class Document:

    def __init__(self, url):
        self.url = url
        self.download()

    def download(self):
        try:
            response = requests.get(self.url)
            if response.status_code == 200:
                self.content = response.content
                return True
            else:
                return False
        except:
            return False

    def persist(self, path):
        Path(path).mkdir(parents=True, exist_ok=True)
        with open(os.path.join(path, quote(self.url).replace('/', '_')), 'wb') as f:
            f.write(self.content)


class HtmlDocument(Document):

    def normalize(self, href):
        if href is not None and href[:4] != 'http':
            href = urllib.parse.urljoin(self.url, href)
        return href

    def parse(self, parse_img=False, parse_text=False, parse_anchors=False):
        #TODO change this method
        
        def parse_images():
            images = []
            i = model.find_all('img')
            for img in i:
                href = self.normalize(img.get('src'))
                images.append(href)
            return images
            
        def parse_links():
            anchors = []
            a = model.find_all('a')
            for anchor in a:
                href = self.normalize(anchor.get('href'))
                text = anchor.text
                anchors.append((text, href))
            return anchors
        
        def parse_text():
            texts = model.findAll(text=True)
            visible_texts = filter(tag_visible, texts)  
            return u" ".join(t.strip() for t in visible_texts)
        
        def tag_visible(element):
            if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
                return False
            if isinstance(element, Comment):
                return False
            return True
            
        
        model = BeautifulSoup(self.content)
        
        if parse_anchors:
            self.anchors = parse_links() 
        if parse_img:
            self.images = parse_images()
        if parse_text:
             self.text = parse_text()

# %% [markdown]
# ### 1.2.2. [15] Main class
#
# The main indexer logic is here. We organize it as a crawler generator that adds certain visited pages to inverted index and saves them on disk.
#
# - `crawl_generator_for_index` method crawles the given website doing BFS, starting from `source` within given `depth`. Considers only inner pages (of a form https://www.reuters.com/...) for visiting. To speed up, doesn't consider for visiting pages with content type other than html: '.pdf', '.mp3', '.avi', '.mp4', '.txt'. If encounters an article page (of a form https://www.reuters.com/article/...), saves its content in a file in `collection_path` folder and populates the inverted index calling `index_doc` method. When done, saves on disk three resulting dictionaries:
#     - `doc_urls`, `doc_id:url`
#     - `index`, `term:[collection_frequency, (doc_id_1, doc_freq_1), (doc_id_2, doc_freq_2), ...]`
#     - `doc_lengths`, `doc_id:doc_length`
#
#     `limit` parameter is given for testing - if not `None`, break the loop when number of saved articles exceeds the `limit` and return without writing dictionaries to disk.
#
#
# - `index_doc` method parses and preprocesses the content of a `doc` and adds it to the inverted index. Also keeps track of document lengths in a `doc_lengths` dictionary.
#
#
# **Extra task \* (no penalty to skip)** In real industrial systems a crawler would pass the links to the dedicated service that would load their contents in a bunch of parallel threads. Implement such a service - get urls as inputs, load page contents in parallel and return filenames on disk, which are then processed by indexer.

# %%
from collections import Counter, defaultdict
from urllib.parse import urlparse
from queue import Queue
import pickle
import os

class Indexer:

    def __init__(self):      
        # dictionaries to populate
        self.doc_urls = {}        
        self.index = {}
        self.doc_lengths = {}
        self.id_counter = 0
        # preprocessor
        self.prep = Preprocessor()
        self.filter_types = ['.pdf', '.mp3', '.avi', '.mp4', '.txt']
        
    
    def crawl_generator_for_index(self, source, depth, collection_path="collection", limit=None):        
        #TODO generate url-s for visiting
        
        def check_limit_less():
            if limit:
                return len(self.doc_urls) < limit
            else: 
                return True
        
        def process_link(link):
            src = HtmlDocument(link)
            checked.add(link)
            src.parse(parse_anchors=True)
            return src
        
        def check_if_html(link):
            url_parsed = urlparse(link)
            for ftype in self.filter_types:
                if ftype in url_parsed:
                    return False
            return True
        
        def check_if_article(link):
            return "https://www.reuters.com/article" in link
        
        def check_if_reuters(link):
            return "https://www.reuters.com" in link
        
        def index_doc(doc):
            #TODO add documents to index
            doc.parse(parse_text=True)
            words = self.prep.preprocess(doc.text)
            # Add url to dict
            self.doc_urls[self.id_counter] = doc.url
            
            #Add doc_lengths to dict
            self.doc_lengths[self.id_counter] = len(words)
            
            # Adding word to index
            for term in words:
                if term in self.index:
                    term_freq, docs_list = self.index[term][0], self.index[term][1:]
                    docs_dict = dict(docs_list)

                    term_freq += 1
                    if self.id_counter in docs_dict:
                        docs_dict[self.id_counter] += 1
                    else:
                        docs_dict[self.id_counter] = 1
                        
                    new_list = [term_freq]
                    new_list.extend(list(docs_dict.items()))
                    self.index[term] = new_list
                else:
                    docs_dict = {self.id_counter: 1}
                    new_list = [1]
                    new_list.extend(list(docs_dict.items()))
                    self.index[term] = new_list
            
            self.id_counter += 1
        
        queue = []
        checked = set()
        tmp_anchor_list = []
        self.id_counter = 0
        
        # Put initial links
        src = process_link(source)
        if check_if_article(src.url):
            src.persist(collection_path)
        index_doc(src)
        yield src
        for _, url in src.anchors:
            if check_if_reuters(url) and check_if_html(url) and url not in checked and url not in queue:
                queue.append(url)
        
            
        # Going until depth is satisified
        for i in range(depth-1):
            print(f"Reached depth {i+1}. Number of links to crawl {len(set(queue))}")
            while (queue):
                try:
                    link = queue.pop(0)
                    # We procceed if the link was not crawled before
                    if link not in checked:
                        src = process_link(link)
                        for _, url in src.anchors:
                            if check_if_reuters(url) and check_if_html(url) and url not in checked and url not in queue:
                                tmp_anchor_list.append(url)
                        if check_limit_less():
                            if check_if_article(src.url):
                                src.persist(collection_path)
                            index_doc(src)
                            yield src  
                        else:
                            return
                except Exception as e:
                    print(e)
            queue.extend(tmp_anchor_list)
            tmp_anchor_list = []

        # save results for later use
        with open('doc_urls.p', 'wb') as fp:
            pickle.dump(self.doc_urls, fp, protocol=pickle.HIGHEST_PROTOCOL)
        with open('inverted_index.p', 'wb') as fp:
            pickle.dump(self.index, fp, protocol=pickle.HIGHEST_PROTOCOL)
        with open('doc_lengths.p', 'wb') as fp:
            pickle.dump(self.doc_lengths, fp, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### 1.2.3. Tests

# %%
indexer = Indexer()
k = 1
for c in indexer.crawl_generator_for_index("https://www.reuters.com/technology", 2, "test_collection", 5):
    print(k, c.url)
    k+=1

assert type(indexer.index) is dict
assert type(indexer.index['reuter']) is list
assert type(indexer.index['reuter'][0]) is int
assert type(indexer.index['reuter'][1]) is tuple
# Out:
# 1 https://www.reuters.com/technology
# Reached depth 1. Number of links to crawl 71
# 2 https://www.reuters.com/
# 3 https://www.reuters.com/home
# 4 https://www.reuters.com/world
# 5 https://www.reuters.com/world/us-politics

# %% [markdown]
# ### 1.2.4. Building an index

# %%
indexer = Indexer()
k = 1
for c in indexer.crawl_generator_for_index("https://www.reuters.com/", 3, "docs_collection"):
    print(k, c.url)
    k+=1
# Out:
# 1 https://www.reuters.com/
# Reached depth 1. Number of links to crawl 122
# 2 https://www.reuters.com/home
# 3 https://www.reuters.com/world
# 4 https://www.reuters.com/world/us-politics
# 5 https://www.reuters.com/world/us
# 6 https://www.reuters.com/world/uk
# 7 https://www.reuters.com/world/china
# 8 https://www.reuters.com/world/india
# 9 https://www.reuters.com/world/americas
# 10 https://www.reuters.com/world/asia-pacific
# 11 https://www.reuters.com/world/europe
# 12 https://www.reuters.com/world/middle-east-africa
# argument of type 'NoneType' is not iterable
# 13 https://www.reuters.com/business
# 14 https://www.reuters.com/business/sustainable-business
# argument of type 'NoneType' is not iterable
# 15 https://www.reuters.com/business/energy
# 16 https://www.reuters.com/business/environment
# 17 https://www.reuters.com/business/finance
# 18 https://www.reuters.com/business/media-telecom
# 19 https://www.reuters.com/business/healthcare-pharmaceuticals
# 20 https://www.reuters.com/business/autos-transportation
# 21 https://www.reuters.com/business/aerospace-defense
# argument of type 'NoneType' is not iterable
# 22 https://www.reuters.com/business/retail-consumer
# argument of type 'NoneType' is not iterable
# 23 https://www.reuters.com/markets
# 24 https://www.reuters.com/markets/us
# 25 https://www.reuters.com/markets/europe
# 26 https://www.reuters.com/markets/asia
# 27 https://www.reuters.com/markets/deals
# 28 https://www.reuters.com/markets/global-market-data
# 29 https://www.reuters.com/markets/stocks
# 30 https://www.reuters.com/markets/bonds
# 31 https://www.reuters.com/markets/funds
# 32 https://www.reuters.com/markets/commodities
# 33 https://www.reuters.com/markets/currencies
# 34 https://www.reuters.com/breakingviews
# 35 https://www.reuters.com/technology
# 36 https://www.reuters.com/investigates/
# 37 https://www.reuters.com/lifestyle
# 38 https://www.reuters.com/lifestyle/sports
# 39 https://www.reuters.com/lifestyle/science
# 40 https://www.reuters.com/lifestyle/wealth
# 41 https://www.reuters.com/lifestyle/oddly-enough
# 42 https://www.reuters.com/pictures
# 43 https://www.reuters.com/video
# 44 https://www.reuters.com
# 45 https://www.reuters.com/article/us-myanmar-politics-past/after-a-decade-of-change-in-myanmar-fear-of-the-past-drives-anti-coup-protests-idUSKBN2A70HI
# 46 https://www.reuters.com/article/us-myanmar-politics-protest/protests-sweep-myanmar-to-oppose-coup-support-suu-kyi-idUSKBN2A702Y
# 47 https://www.reuters.com/news/picture/pictures-report-idUSRTR4Z5HC
# 48 https://www.reuters.com/article/us-healthcare-coronavirus-usa-congress/u-s-treasurys-yellen-americans-earning-60000-should-get-stimulus-checks-idUSKBN2A70JE
# 49 https://www.reuters.com/article/us-global-oil-hedgefunds-focus/hedge-funds-bet-on-oils-big-comeback-after-pandemic-hobbles-producers-idUSKBN2A70IM
# 50 https://www.reuters.com/article/us-dialog-m-a-renesas/chip-designer-dialog-confirms-6-billion-renesas-offer-talks-idUSKBN2A70JX
# 51 https://www.reuters.com/article/us-india-disaster/himalayan-glacier-breaks-in-india-around-125-missing-in-floods-idUSKBN2A706O
# 52 https://www.reuters.com/theWire
# 53 https://www.reuters.com/article/us-health-coronavirus-britain-vaccine-bo/uk-says-covid-19-booster-and-annual-vaccinations-very-probable-idUSKBN2A70A5?il=0
# 54 https://www.reuters.com/article/us-ecuador-election/ecuadoreans-vote-for-president-as-voters-lean-toward-socialism-idUSKBN2A70CU?il=0
# 55 https://www.reuters.com/article/us-myanmar-politics-past/after-a-decade-of-change-in-myanmar-fear-of-the-past-drives-anti-coup-protests-idUSKBN2A70HI?il=0
# 56 https://www.reuters.com/article/us-myanmar-politics-protest/protests-sweep-myanmar-to-oppose-coup-support-suu-kyi-idUSKBN2A702Y?il=0
# 57 https://www.reuters.com/article/us-healthcare-coronavirus-usa-congress/u-s-treasurys-yellen-americans-earning-60000-should-get-stimulus-checks-idUSKBN2A70JE?il=0
# 58 https://www.reuters.com/article/us-dialog-m-a-renesas/chip-designer-dialog-confirms-6-billion-renesas-offer-talks-idUSKBN2A70JX?il=0
# 59 https://www.reuters.com/article/us-retail-trading-yellen/u-s-treasury-secretary-yellen-too-soon-to-say-if-changes-needed-to-address-market-volatility-idUSKBN2A70J4?il=0
# 60 https://www.reuters.com/article/us-china-internet-anti-monopoly/china-issues-new-anti-monopoly-rules-targeting-its-tech-giants-idUSKBN2A70DT?il=0
# 61 https://www.reuters.com/article/us-britain-eu-exports/exports-from-uk-to-eu-down-68-since-brexit-trade-deal-say-hauliers-idUSKBN2A70G3?il=0
# 62 https://www.reuters.com/article/us-global-oil-hedgefunds-focus/hedge-funds-bet-on-oils-big-comeback-after-pandemic-hobbles-producers-idUSKBN2A70IM?il=0
# 63 https://www.reuters.com/article/us-britain-eu-nireland-coveney/ireland-open-to-modest-extensions-to-northern-ireland-brexit-grace-periods-idUSKBN2A70IG?il=0
# 64 https://www.reuters.com/article/us-india-disaster/himalayan-glacier-breaks-in-india-around-125-missing-in-floods-idUSKBN2A706O?il=0
# 65 https://www.reuters.com/article/us-israel-cenbank-reserves/bank-of-israel-buys-6-8-billion-of-forex-in-january-reserves-jump-to-new-record-idUSKBN2A70G5?il=0
# 66 https://www.reuters.com/article/us-israel-netanyahu-protests/at-anti-netanyahu-protests-in-israel-pink-is-the-new-black-idUSKBN2A70DN?il=0
# 67 https://www.reuters.com/article/us-myanmar-politics-pope/pope-calls-on-myanmar-leaders-to-serve-common-good-seek-democratic-harmony-idUSKBN2A70DY?il=0
# 68 https://www.reuters.com/article/us-swiss-eu/eu-ambassador-to-switzerland-says-treaty-talks-finished-blick-idUSKBN2A70DF?il=0
# 69 https://www.reuters.com/article/us-turkey-security-bogazici/turkey-jails-four-pending-trial-over-university-protests-prosecutor-idUSKBN2A70DD?il=0
# 70 https://www.reuters.com/article/us-health-coronavirus-india-diplomacy/vaccine-diplomacy-india-seeks-to-rival-china-with-broad-shipments-idUSKBN2A70C8?il=0
# 71 https://www.reuters.com/article/us-myanmar-politics-timeline/timeline-the-week-since-myanmars-coup-idUSKBN2A70D6?il=0
# 72 https://www.reuters.com/article/us-pope-women/pope-francis-appoints-more-women-to-vatican-posts-idUSKBN2A70CZ?il=0
# 73 https://www.reuters.com/article/us-health-coronavirus-britain-vaccine-bo/uk-says-covid-19-booster-and-annual-vaccinations-very-probable-idUSKBN2A70A5
# 74 https://www.reuters.com/article/us-health-coronavirus-bangladesh-vaccine/the-wait-is-over-bangladesh-begins-covid-19-vaccinations-idUSKBN2A70I0
# 75 https://www.reuters.com/article/us-health-coronavirus-usa-cdc/59-3-million-doses-of-covid-19-vaccines-distributed-39-million-administered-u-s-cdc-idUSKBN2A701B
# 76 https://www.reuters.com/article/us-football-nfl-superbowl-fans/no-cheering-no-parties-covid-19-forces-different-super-bowl-sunday-for-fans-idUSKBN2A60QB
# 77 https://www.reuters.com/article/idUSKBN2A7007
# 78 https://www.reuters.com/article/idUSKBN2A60RT
# 79 https://www.reuters.com/article/us-health-coronavirus-masks/one-u-s-companys-risky-effort-to-build-a-new-mask-factory-during-covid-idUSKBN2A516H
# 80 https://www.reuters.com/article/us-health-coronavirus-europe-births/lockdown-bambino-bust-9-months-on-italian-births-fall-22-percent-idUSKBN2A50MY
# 81 https://www.reuters.com/article/us-space-exploration-china-mars/mars-ready-for-its-close-up-china-releases-space-probes-first-image-idUSKBN2A51Z9
# 82 https://www.reuters.com/article/us-iran-nuclear-usa/u-s-must-lift-curbs-before-iran-rejoins-deal-khamenei-cites-final-stance-idUSKBN2A7093
# 83 https://www.reuters.com/article/us-china-aluminium-emissions/china-aluminium-sector-must-shut-inefficient-coal-power-to-meet-climate-goals-report-idUSKBN2A70KZ
# 84 https://www.reuters.com/article/us-usa-immigration-centralamerica/biden-administration-suspends-trump-asylum-deals-with-el-salvador-guatemala-honduras-idUSKBN2A702Q
# 85 https://www.reuters.com/article/us-pope-women/pope-francis-appoints-more-women-to-vatican-posts-idUSKBN2A70CZ
# 86 https://www.reuters.com/article/us-israel-netanyahu-protests/at-anti-netanyahu-protests-in-israel-pink-is-the-new-black-idUSKBN2A70DN
# 87 https://www.reuters.com/article/us-britain-eu-exports/exports-from-uk-to-eu-down-68-since-brexit-trade-deal-say-hauliers-idUSKBN2A70G3
# 88 https://www.reuters.com/news/pictures
# 89 https://www.reuters.com/news/picture/tampas-popular-strip-clubs-eerily-quiet-idUSRTX8YD1I
# 90 https://www.reuters.com/news/picture/photos-of-the-week-idUSRTX8YPRQ
# 91 https://www.reuters.com/finance
# 92 https://www.reuters.com/article/us-retail-trading-yellen/u-s-treasury-secretary-yellen-too-soon-to-say-if-changes-needed-to-address-market-volatility-idUSKBN2A70J4
# 93 https://www.reuters.com/article/us-g4s-m-a-garda-world/g4s-to-hold-talks-for-head-to-head-takeover-auction-the-telegraph-idUSKBN2A60RB
# 94 https://www.reuters.com/article/us-retail-trading-bonds-analysis/analysis-the-other-winners-of-the-reddit-fueled-rallies-convertible-debt-idUSKBN2A522A
# 95 https://www.reuters.com/article/us-israel-cenbank-reserves/bank-of-israel-buys-6-8-billion-of-forex-in-january-reserves-jump-to-new-record-idUSKBN2A70G5
# 96 https://www.reuters.com/article/us-taiwan-forex/taiwan-punishes-deutsche-bank-others-in-currency-speculation-case-idUSKBN2A705J
# 97 https://www.reuters.com/article/us-health-coronavirus-britain-budget/uk-plans-to-tax-firms-that-profited-from-pandemic-sunday-times-idUSKBN2A60TE
# 98 https://www.reuters.com/article/us-ecuador-election/ecuadoreans-vote-for-president-as-voters-lean-toward-socialism-idUSKBN2A70CU
# 99 https://www.reuters.com/article/us-china-internet-anti-monopoly/china-issues-new-anti-monopoly-rules-targeting-its-tech-giants-idUSKBN2A70DT
# 100 https://www.reuters.com/article/us-britain-eu-nireland-coveney/ireland-open-to-modest-extensions-to-northern-ireland-brexit-grace-periods-idUSKBN2A70IG
# 101 https://www.reuters.com/article/us-china-internet-clubhouse/chinese-users-flock-to-u-s-chat-app-clubhouse-evading-censors-idUSKBN2A705H
# 102 https://www.reuters.com/article/us-microsoft-donations/microsoft-halts-donations-through-2022-to-lawmakers-who-opposed-biden-certification-idUSKBN2A52IT
# 103 https://www.reuters.com/article/us-retail-trading/gamestop-shares-halt-slide-after-robinhood-lifts-trading-curbs-idUSKBN2A51QV
# 104 https://www.reuters.com/politics
# 105 https://www.reuters.com/article/us-health-coronavirus-usa-congress/democrats-clear-path-for-approval-of-bidens-1-9-trillion-covid-package-idUSKBN2A514V
# 106 https://www.reuters.com/article/us-health-coronavirus-usa-wage/biden-says-he-does-not-expect-minimum-wage-hike-to-be-in-covid-19-relief-bill-idUSKBN2A52UR
# 107 https://www.reuters.com/article/us-usa-biden-refugees/biden-to-raise-current-u-s-refugee-cap-from-historic-lows-idUSKBN2A602W
# 108 https://www.reuters.com/article/us-daimler-trucks-divestiture/daimler-to-keep-protective-hand-on-truck-unit-after-spin-off-idUSKBN2A60QT
# 109 https://www.reuters.com/article/us-oscar-health-ipo/alphabet-backed-oscar-health-files-for-ipo-as-telehealth-market-booms-idUSKBN2A52U8
# 110 https://www.reuters.com/article/us-verizon-tracfone-fcc/u-s-states-ask-fcc-to-scrutinize-verizons-plan-to-buy-tracfone-idUSKBN2A52SH
# 111 https://www.reuters.com/investigates/special-report/tips/
# 'HtmlDocument' object has no attribute 'content'
# 112 https://www.reuters.com/tools/podcasts
# 113 https://www.reuters.com/tools/mobile
# 114 https://www.reuters.com/article/us-reuters-editorial-leadership/reuters-editorial-leadership-idUSKBN1KE2SD
# 115 https://www.reuters.com/fact-check
# 116 https://www.reuters.com/info/disclaimer
# 117 https://www.reuters.com/advertising-guidelines
# 118 https://www.reuters.com/terms-of-use
# Reached depth 2. Number of links to crawl 872
# 119 https://www.reuters.com/article/us-health-coronavirus-india-diplomacy/vaccine-diplomacy-india-seeks-to-rival-china-with-broad-shipments-idUSKBN2A70C8
# 120 https://www.reuters.com/article/us-turkey-security-bogazici/turkey-jails-four-pending-trial-over-university-protests-prosecutor-idUSKBN2A70DD
# 121 https://www.reuters.com/news/archive/worldnews?view=page&page=2&pageSize=10
# 122 https://www.reuters.com/video/2021/02/07/over-100-feared-dead-after-himalayan-gla?videoId=725479592&videoChannel=117760
# 123 https://www.reuters.com/video/2021/02/07/conjoined-yemeni-twins-flown-to-amman-fo?videoId=725478771&videoChannel=117760
# 124 https://www.reuters.com/video/2021/02/07/tens-of-thousands-rally-against-myanmar?videoId=725473451&videoChannel=117760
# 125 https://www.reuters.com/video/2021/02/07/oxford-covid-shot-less-effective-on-safr?videoId=725472630&videoChannel=117760
# 126 https://www.reuters.com/video/2021/02/07/chilean-village-burns-over-fatal-police?videoId=725466391&videoChannel=117760
# 127 https://www.reuters.com/article/us-usa-security-biden-trump/biden-says-trump-should-not-receive-intelligence-briefings-cbs-interview-idUSKBN2A52UN
# 128 https://www.reuters.com/article/us-usa-economy-inequality/u-s-treasury-secretary-yellen-warns-of-lasting-impact-of-covid-on-black-americans-idUSKBN2A52M0
# 129 https://www.reuters.com/article/us-usa-fed-singh/biden-to-name-new-york-feds-singh-as-deputy-security-adviser-idUSKBN2A52TF
# 130 https://www.reuters.com/article/us-usa-chile-arms/u-s-state-department-approves-first-potential-weapons-sales-under-biden-says-pentagon-idUSKBN2A52MC
# 131 https://www.reuters.com/article/us-usa-tech-section-230/u-s-senators-propose-limiting-liability-shield-for-social-media-platforms-idUSKBN2A5233
# 132 https://www.reuters.com/article/us-usa-trump-impeachment-defense/trump-impeachment-defense-to-attack-the-process-lawyer-says-idUSKBN2A52B1
# 133 https://www.reuters.com/news/archive/politicsnews?view=page&page=2&pageSize=10
# 134 https://www.reuters.com/video/2021/02/05/dems-clear-path-for-19-trillion-covid-pa?videoId=725409552&videoChannel=1003
# 135 https://www.reuters.com/video/2021/02/05/imperative-that-unemployment-benefits-co?videoId=725405210&videoChannel=1003
# 136 https://www.reuters.com/video/2021/02/05/senate-passes-budget-plan-to-advance-cov?videoId=725397930&videoChannel=1003
# 137 https://www.reuters.com/video/2021/02/05/house-votes-to-remove-greene-from-commit?videoId=725353768&videoChannel=1003
# 138 https://www.reuters.com/video/2021/02/04/senate-dems-take-first-step-on-bidens-re?videoId=725348738&videoChannel=1003
# 'HtmlDocument' object has no attribute 'content'
# 139 https://www.reuters.com/article/us-usa-avalanche/four-skiers-killed-four-rescued-in-utah-avalanche-idUSKBN2A70JZ
# 140 https://www.reuters.com/article/us-usa-immigration-mayorkas/bidens-homeland-security-czar-vows-to-fight-domestic-terrorism-idUSKBN2A60TG
# 141 https://www.reuters.com/article/us-health-coronavirus-chicago-teachers/chicago-teachers-district-talks-in-stalemate-over-covid-re-opening-plan-idUSKBN2A52MX
# 142 https://www.reuters.com/article/us-global-race-usa-ohio/fired-ohio-policeman-pleads-not-guilty-in-andre-hills-killing-bond-set-at-3-million-idUSKBN2A52CM
# 143 https://www.reuters.com/article/us-usa-immigration-guatemala-asylum/u-s-halts-asylum-seeker-pact-with-guatemala-says-guatemalan-government-idUSKBN2A605G
# 144 https://www.reuters.com/news/archive/domesticnews?view=page&page=2&pageSize=10
# 145 https://www.reuters.com/article/uk-health-coronavirus-britain-vaccine-bo/uk-says-covid-19-booster-and-annual-vaccinations-very-probable-idUSKBN2A70A9
# 146 https://www.reuters.com/article/uk-health-coronavirus-astrazeneca-varian/oxford-astrazeneca-covid-shot-less-effective-against-south-african-variant-study-idUSKBN2A60RH
# 147 https://www.reuters.com/article/uk-health-coronavirus-britain-vaccinatio/more-than-12-million-britons-have-received-first-covid-19-vaccine-dose-idUSKBN2A70L9
# 148 https://www.reuters.com/article/uk-britain-violence/uks-metropolitan-police-investigate-fatal-stabbing-in-london-idUSKBN2A60RN
# 149 https://www.reuters.com/article/uk-health-coronavirus-britain-budget/uk-plans-to-tax-firms-that-profited-from-pandemic-sunday-times-idUSKBN2A60T0
# 150 https://www.reuters.com/article/uk-soccer-england-tot-wba-report/kane-returns-to-help-tottenham-back-to-winning-ways-idUSKBN2A70HS
# 151 https://www.reuters.com/article/uk-soccer-england-wlv-lei-report/wolves-and-leicester-lack-inspiration-in-stalemate-idUSKBN2A70L5
# 152 https://www.reuters.com/article/uk-health-coronavirus-britain-passport/britain-will-not-introduce-covid-19-vaccine-passports-idUSKBN2A708R
# 153 https://www.reuters.com/article/uk-britain-violence/uk-police-investigating-multiple-violent-incidents-in-south-london-idUSKBN2A52UT
# 154 https://www.reuters.com/article/uk-health-coronavirus-tennis-murray/murray-questions-ltas-covid-protocols-after-positive-test-idUSKBN2A702G
# 155 https://www.reuters.com/news/archive/ukdomestic?view=page&page=2&pageSize=10
# 156 https://www.reuters.com/video/2017/08/22/over-100-feared-dead-after-himalayan-gla?videoId=725479592&videoChannel=117760
# 157 https://www.reuters.com/video/2017/08/22/conjoined-yemeni-twins-flown-to-amman-fo?videoId=725478771&videoChannel=117760
# 158 https://www.reuters.com/video/2017/02/07/tens-of-thousands-rally-against-myanmar?videoId=725473451&videoChannel=117760
# 159 https://www.reuters.com/video/2017/08/22/oxford-covid-shot-less-effective-on-safr?videoId=725472630&videoChannel=117760
# 160 https://www.reuters.com/article/us-usa-china/blinken-presses-china-on-xinjiang-hong-kong-in-call-with-beijings-top-diplomat-idUSKBN2A604Y
# 161 https://www.reuters.com/article/us-health-coronavirus-indonesia-vaccine/exclusive-indonesia-approves-chinas-sinovac-vaccine-for-the-elderly-idUSKBN2A60I0
# 162 https://www.reuters.com/article/us-health-coronavirus-vaccine-sinovac/china-approves-sinovac-biotech-covid-19-vaccine-for-general-public-use-idUSKBN2A60AY
# 163 https://www.reuters.com/article/us-china-pollution/china-to-launch-public-platform-to-track-crack-down-on-polluters-idUSKBN2A605E
# 164 https://www.reuters.com/article/us-china-environment-wildlife/china-adds-more-than-500-species-to-wildlife-protection-list-idUSKBN2A604H
# 165 https://www.reuters.com/article/us-health-coronavirus-china-cases/mainland-china-reports-12-new-covid-19-cases-vs-20-a-day-earlier-idUSKBN2A6030
# 166 https://www.reuters.com/article/us-health-coronavirus-china-indonesia-va/china-ready-to-increase-cooperation-with-indonesia-on-covid-19-vaccines-xinhua-idUSKBN2A52R3
# 167 https://www.reuters.com/article/us-laix-stocks/laix-shares-soar-other-small-chinese-educational-stocks-gain-idUSKBN2A52J4
# 168 https://www.reuters.com/article/us-health-coronavirus-china-nepal/china-to-give-first-batch-of-covid-19-vaccine-aid-for-nepal-xinhua-idUSKBN2A52H2
# 169 https://www.reuters.com/article/us-estee-lauder-results/estee-lauder-posts-surprise-revenue-growth-on-china-demand-shares-soar-idUSKBN2A51CH
# 170 https://www.reuters.com/article/us-taiwan-china-security/chinas-latest-weapon-against-taiwan-the-sand-dredger-idUSKBN2A51EJ
# 171 https://www.reuters.com/article/us-retail-trading-china/the-police-will-visit-you-why-gamestonk-wont-come-to-china-idUSKBN2A50HJ
# 172 https://www.reuters.com/article/us-china-britain/china-takes-aim-again-at-bbc-as-dispute-with-britain-intensifies-idUSKBN2A50DY
# 173 https://www.reuters.com/article/us-china-performers-ethics/china-says-actors-must-follow-moral-guidelines-or-face-bans-idUSKBN2A51DN
# 174 https://www.reuters.com/article/us-china-swinefever-variant/chinese-researchers-find-natural-mutation-in-african-swine-fever-virus-idUSKBN2A5187
# 175 https://www.reuters.com/news/archive/china-news?view=page&page=2&pageSize=10
# 176 https://www.reuters.com/article/india-disaster/himalayan-glacier-breaks-in-india-around-125-missing-in-floods-idUSKBN2A706M
# 177 https://www.reuters.com/article/india-disaster/uttarakhand-chief-minister-says-about-125-missing-after-glacier-collapse-idUSKBN2A70GP
# 178 https://www.reuters.com/article/cricket-test-ind-eng/india-risk-follow-on-against-england-after-bess-wrecks-middle-order-idUSKBN2A704J
# 179 https://www.reuters.com/article/health-coronavirus-afghanistan-vaccine/first-doses-of-covid-19-vaccine-arrive-in-afghanistan-from-india-idUSKBN2A707M
# 180 https://www.reuters.com/article/health-coronavirus-india-diplomacy/vaccine-diplomacy-india-seeks-to-rival-china-with-broad-shipments-idUSKBN2A70BR
# 181 https://www.reuters.com/article/health-coronavirus-india-vaccine/india-asks-states-to-speed-up-covid-19-vaccination-idUSKBN2A60KB
# 182 https://www.reuters.com/article/cricket-test-ind-eng/roots-double-century-in-100th-test-puts-england-in-control-versus-india-idUSKBN2A608Y
# 183 https://www.reuters.com/article/india-farms-protests/tractors-trucks-block-indias-roads-as-farm-protests-widen-idUSKBN2A605Z
# 184 https://www.reuters.com/article/india-twitter/playing-with-fire-twitters-india-snub-sparks-debate-on-compliance-free-speech-idUSKBN2A60DK
# 185 https://www.reuters.com/article/india-kashmir/india-restoring-fast-mobile-internet-in-kashmir-after-18-months-idUSKBN2A5239
# 186 https://www.reuters.com/article/cricket-test-ind-eng-root/milestone-man-root-keen-to-cash-in-on-purple-patch-idUSKBN2A51MK
# 187 https://www.reuters.com/news/archive/india-only?view=page&page=2&pageSize=10
# 188 https://www.reuters.com/article/us-health-coronavirus-astrazeneca-varian/oxford-astrazeneca-covid-shot-less-effective-against-south-african-variant-study-idUSKBN2A60SH
# 189 https://www.reuters.com/article/us-chile-crime-protest/protests-erupt-in-chilean-lakeside-resort-after-street-performer-shot-by-police-idUSKBN2A60NP
# 190 https://www.reuters.com/article/us-mexico-violence-guatemala/nearly-all-victims-of-mexican-massacre-confirmed-as-guatemalans-idUSKBN2A704D
# 191 https://www.reuters.com/article/us-health-coronavirus-brazil/brazil-gets-first-active-ingredients-for-astrazeneca-vaccine-from-china-idUSKBN2A60S7
# 192 https://www.reuters.com/article/us-amazon-engines-natural-gas-exclusive/exclusive-amazon-orders-hundreds-of-trucks-that-run-on-natural-gas-idUSKBN2A52ML
# 193 https://www.reuters.com/article/us-cuba-economy-reform/cuba-opens-door-to-most-small-business-initiatives-idUSKBN2A60JR
# 194 https://www.reuters.com/article/us-health-coronavirus-bolivia/bolivia-funeral-homes-cemeteries-overwhelmed-as-covid-19-deaths-mount-idUSKBN2A60KX
# 195 https://www.reuters.com/article/us-health-coronavirus-brazil-pfizer/pfizer-applies-to-register-covid-19-vaccine-in-brazil-idUSKBN2A60JZ
# 196 https://www.reuters.com/article/us-health-coronavirus-mexico/mexico-city-families-see-some-relief-from-pandemic-with-home-visits-idUSKBN2A607T
# 197 https://www.reuters.com/article/us-health-coronavirus-mexico/mexicos-confirmed-coronavirus-death-toll-shoots-past-164000-idUSKBN2A6020
# 198 https://www.reuters.com/article/us-health-coronavirus-brazil-sputnik/brazil-drugmaker-seeks-contract-regulatory-ok-for-russian-vaccine-next-week-idUSKBN2A52J8
# 199 https://www.reuters.com/article/us-people-christopher-plummer/christopher-plummer-sound-of-music-star-of-stage-and-screen-dead-at-91-idUSKBN2A52BO
# 200 https://www.reuters.com/article/us-imf-argentina/imfs-georgieva-tells-argentina-it-takes-two-to-tango-in-deal-talks-idUSKBN2A52V3
# 201 https://www.reuters.com/article/us-health-coronavirus-mexico-cansino/cansino-vaccine-seeks-emergency-approval-in-mexico-foreign-minister-idUSKBN2A52QT
# 202 https://www.reuters.com/news/archive/americas-test-2?view=page&page=2&pageSize=10
# 203 https://www.reuters.com/article/us-tennis-ausopen/djokovic-has-not-much-respect-for-kyrgios-off-court-idUSKBN2A704P
# 204 https://www.reuters.com/article/us-myanmar-politics-pope/pope-calls-on-myanmar-leaders-to-serve-common-good-seek-democratic-harmony-idUSKBN2A70DY
# 205 https://www.reuters.com/article/us-myanmar-politics-timeline/timeline-the-week-since-myanmars-coup-idUSKBN2A70D6
# 206 https://www.reuters.com/article/us-health-coronavirus-afghanistan-vaccin/first-doses-of-covid-19-vaccine-arrive-in-afghanistan-from-india-idUSKBN2A707O
# 207 https://www.reuters.com/article/us-myanmar-politics-telenor/myanmar-data-network-is-restored-says-telenor-idUSKBN2A70B6
# 208 https://www.reuters.com/article/us-malaysia-rohingya/over-30-rohingya-caught-arriving-in-malaysia-by-boat-in-january-police-idUSKBN2A709B
# 209 https://www.reuters.com/article/us-tennis-murrayriver/tennis-briton-evans-claims-maiden-atp-title-at-murray-river-open-idUSKBN2A7055
# 210 https://www.reuters.com/article/us-myanmar-politics-shots/shots-heard-as-police-break-up-protest-in-southeastern-town-of-myawaddy-video-idUSKBN2A7076
# 211 https://www.reuters.com/article/us-philippines-quake/magnitude-6-3-earthquake-strikes-southern-philippines-idUSKBN2A704F
# 212 https://www.reuters.com/article/us-tennis-yarravalley/barty-outmuscles-muguruza-to-win-yarra-valley-classic-idUSKBN2A701S
# 213 https://www.reuters.com/article/us-myanmar-politics/tens-of-thousands-protest-myanmar-coup-despite-internet-ban-idUSKBN2A52DE
# 214 https://www.reuters.com/article/us-health-coronavirus-tennis-murray/tennis-murray-questions-ltas-covid-protocols-after-positive-test-idUSKBN2A702I
# 215 https://www.reuters.com/article/us-australia-bushfires/firefighters-in-western-australia-get-upper-hand-on-several-bushfires-idUSKBN2A702A
# 216 https://www.reuters.com/news/archive/rcom-apac?view=page&page=2&pageSize=10
# 217 https://www.reuters.com/article/us-health-coronavirus-britain-vaccinatio/more-than-12-million-britons-have-received-first-covid-19-vaccine-dose-idUSKBN2A70LD
# 218 https://www.reuters.com/article/us-italy-politics-salvini/italys-5-star-league-open-up-to-draghi-government-await-policy-plans-idUSKBN2A60G6
# 219 https://www.reuters.com/article/us-iran-nuclear-europe-usa/france-says-held-in-depth-talks-with-u-s-britain-germany-on-iran-idUSKBN2A52L5
# 220 https://www.reuters.com/article/us-iran-nuclear-europe/blinken-discusses-iran-with-uk-french-german-ministers-idUSKBN2A526T
# 221 https://www.reuters.com/article/us-libya-security-un-britain/western-powers-welcome-libyan-interim-government-idUSKBN2A52OJ
# 222 https://www.reuters.com/article/us-global-markets/world-shares-scale-new-peak-on-stimulus-hopes-oil-gains-idUSKBN2A501F
# 223 https://www.reuters.com/article/us-health-coronavirus-britain-france/collaboration-needed-in-fight-against-covid-19-uk-and-french-leaders-agree-idUSKBN2A52K8
# 224 https://www.reuters.com/article/us-germany-politics-nordstream/analysis-russias-navalny-case-casts-shadow-on-german-politics-ahead-of-election-idUSKBN2A51SU
# 225 https://www.reuters.com/article/us-britain-kbr-sfo/uk-prosecutor-loses-battle-against-kbr-over-extra-territorial-reach-idUSKBN2A51F7
# 226 https://www.reuters.com/article/us-health-coronavirus-vaccines-europe-in/countdown-to-catastrophe-inside-europes-fight-for-covid-shots-idUSKBN2A50I1
# 227 https://www.reuters.com/article/us-health-coronavirus-astrazeneca-varian/oxford-says-covid-19-vaccine-with-astrazeneca-works-against-uk-variant-idUSKBN2A51K0
# 228 https://www.reuters.com/article/us-global-markets-themes/take-five-dollar-signs-idUSKBN2A51DQ
# 229 https://www.reuters.com/article/us-health-coronavirus-britain-curevac/britain-to-work-with-germanys-curevac-on-vaccines-against-coronavirus-variants-idUSKBN2A51JT
# 230 https://www.reuters.com/article/us-germany-politics-laschet-exclusive/exclusive-navalny-affair-no-grounds-to-cancel-nord-stream-pipeline-new-german-cdu-chief-says-idUSKBN2A51FL
# 231 https://www.reuters.com/article/us-health-coronavirus-germany/data-prove-coronavirus-mutations-are-more-infectious-german-official-idUSKBN2A5116
# 232 https://www.reuters.com/article/us-bnpparibas-results/bnp-paribas-expects-end-to-trading-boom-covid-loan-pain-to-ease-idUSKBN2A50JY
# 233 https://www.reuters.com/news/archive/rcom-europe?view=page&page=2&pageSize=10
# 234 https://www.reuters.com/article/us-iran-yemen-un/u-n-envoy-griffiths-in-iran-for-first-time-to-discuss-yemen-crisis-tv-idUSKBN2A707I
# 235 https://www.reuters.com/article/us-gulf-qatar-egypt/egypt-frees-al-jazeera-journalist-after-four-years-in-detention-idUSKBN2A60PJ
# 236 https://www.reuters.com/article/us-iran-usa-nuclear/irans-top-diplomat-urges-biden-to-return-to-nuclear-deal-idUSKBN2A60GJ
# 237 https://www.reuters.com/article/us-usa-saudi-politics/u-s-secretary-of-state-blinken-saudi-foreign-minister-discuss-yemen-human-rights-idUSKBN2A609U
# 238 https://www.reuters.com/article/us-yemen-security-usa/u-s-to-drop-houthi-terrorist-designation-due-to-yemen-crisis-idUSKBN2A600Z
# 239 https://www.reuters.com/article/us-icc-palestinians-israel/icc-ruling-brings-hope-for-palestinians-dismay-for-israelis-idUSKBN2A60N9
# 240 https://www.reuters.com/article/us-libya-security/libya-power-brokers-welcome-accord-but-challenges-lie-ahead-idUSKBN2A60HQ
# 241 https://www.reuters.com/news/archive/middle-east?view=page&page=2&pageSize=10
# 242 https://www.reuters.com/article/us-usa-stocks/sp-500-nasdaq-post-biggest-weekly-gains-since-early-november-idUSKBN2A51BX
# 243 https://www.reuters.com/article/us-health-coronavirus-britain-vaccine-pa/vaccine-passports-path-back-to-normality-or-problem-in-the-making-idUSKBN2A4134
# 244 https://www.reuters.com/article/us-britain-banks-racism-insight/after-pledging-disclosure-many-uk-banks-still-silent-on-race-diversity-data-idUSKBN2A30L5
# 245 https://www.reuters.com/video/2020/12/10/spanish-firms-swap-parties-for-gift-boxe?videoId=722927510&videoChannel=118314
# 246 https://www.reuters.com/video/2020/12/08/the-toys-turning-coronavirus-into-childs?videoId=722825167&videoChannel=118314
# 247 https://www.reuters.com/video/2020/12/02/spaniards-seek-big-bright-and-airtight-h?videoId=722624779&videoChannel=118314
# 248 https://www.reuters.com/article/uk-health-coronavirus-finance-breakingvi/breakingviews-corona-capital-peloton-star-spac-italian-bank-idUSKBN2A52AV
# 249 https://www.reuters.com/article/us-britain-brexit-breakingviews/breakingviews-review-empireland-puts-modern-britain-on-couch-idUSKBN2A519S
# 250 https://www.reuters.com/article/us-health-coronavirus-finance-breakingvi/breakingviews-corona-capital-bnp-beer-planes-paint-debt-idUSKBN2A5181
# 251 https://www.reuters.com/article/us-usa-stocks-weekahead/wall-street-week-ahead-gamestop-frenzy-reveals-potential-for-broader-market-stress-idUSKBN2A52L1
# 252 https://www.reuters.com/video/2021/02/05/sp-nasdaq-post-best-weekly-gains-in-thre?videoId=725411483&videoChannel=5
# 253 https://www.reuters.com/video/2021/02/05/big-correction-could-come-in-spring-geor?videoId=725408899&videoChannel=5
# 254 https://www.reuters.com/video/2021/02/05/oil-prices-hit-a-one-year-high?videoId=725407031&videoChannel=5
# 255 https://www.reuters.com/article/us-health-coronavirus-kroger/kroger-to-pay-100-to-workers-who-get-covid-19-vaccination-idUSKBN2A52SJ
# 256 https://www.reuters.com/article/us-usa-economy/stalling-u-s-labor-market-bolsters-bidens-drive-for-big-stimulus-package-idUSKBN2A50EZ
# 257 https://www.reuters.com/news/archive/businessnews?view=page&page=2&pageSize=10
# 258 https://www.reuters.com/finance/markets
# 259 https://www.reuters.com/finance/markets/index?symbol=.SPX
# 260 https://www.reuters.com/finance/markets/index?symbol=.DJI
# 261 https://www.reuters.com/finance/markets/index?symbol=.FTSE
# 262 https://www.reuters.com/finance/markets/index?symbol=.N225
# 263 https://www.reuters.com/finance/currencies/quote?srcAmt=1&srcCurr=USD&destAmt=&destCurr=EUR
# 264 https://www.reuters.com/finance/currencies/quote?srcAmt=1&srcCurr=USD&destAmt=&destCurr=GBP
# 265 https://www.reuters.com/finance/currencies/quote?srcAmt=1&srcCurr=USD&destAmt=&destCurr=JPY
# 266 https://www.reuters.com/article/us-southkorea-energy-windfarm/south-korea-unveils-43-billion-plan-for-worlds-largest-offshore-wind-farm-idUSKBN2A512D
# 267 https://www.reuters.com/article/us-indonesia-mining-environment/exclusive-facing-green-pressure-indonesia-halts-deep-sea-mining-disposal-idUSKBN2A50UO
# 268 https://www.reuters.com/article/us-usa-refiners-renewables/u-s-refiners-talk-up-renewable-projects-after-a-year-of-lousy-fuel-demand-idUSKBN2A30O2
# 269 https://www.reuters.com/article/us-exxon-mobil-management-breakingviews/breakingviews-jeff-ubbens-soft-touch-could-help-hardened-exxon-idUSKBN2A52BA
# 270 https://www.reuters.com/video/?chan=9hh451f6
# 271 https://www.reuters.com/video/2021/02/01/shell-targets-power-trading-and-hydrogen?videoId=725117274&videoChannel=118285
# 272 https://www.reuters.com/video/2021/01/27/robert-downey-jr-launches-funds-in-envir?videoId=724895756&videoChannel=118285
# 273 https://www.reuters.com/video/2021/01/27/new-models-to-be-electric-by-early-2030s?videoId=724877195&videoChannel=118285
# 274 https://www.reuters.com/subjects/sustainable-business/environmental-impact
# 275 https://www.reuters.com/article/uk-china-aluminium-emissions/china-aluminium-sector-must-shut-inefficient-coal-power-to-meet-climate-goals-report-idUSKBN2A70LF
# 276 https://www.reuters.com/subjects/sustainable-business/workplace-equality
# 277 https://www.reuters.com/article/us-germany-women-companies/german-cabinet-agrees-quota-for-women-on-company-boards-idUSKBN29B16U
# 278 https://www.reuters.com/article/us-goldman-sachs-partners/goldman-sachs-highlights-diversity-in-new-partner-class-idUSKBN27S2Z0
# 279 https://www.reuters.com/article/us-wall-street-diversity-marty-chavez/former-goldman-executive-chavez-reflects-on-diversity-on-wall-street-idUSKBN2752UU
# 280 https://www.reuters.com/subjects/sustainable-business/tech-trust
# 281 https://www.reuters.com/article/us-uber-electric-vehicles/uber-expands-green-trip-option-to-over-1400-cities-in-north-america-idUSKBN29H1ZT
# 282 https://www.reuters.com/article/us-twitter-content-hate/twitter-expands-hate-speech-rules-to-include-race-ethnicity-idUSKBN28D03U
# 283 https://www.reuters.com/article/us-tech-sap/sap-pledges-to-spend-more-on-social-diverse-businesses-idUSKBN26R0C8
# 284 https://www.reuters.com/subjects/sustainable-business/responsible-investing
# 285 https://www.reuters.com/article/us-ecb-climate-lagarde/ecb-should-think-green-when-picking-assets-policymakers-idUSKBN29U0TA
# 286 https://www.reuters.com/article/us-britain-boe-environment/bank-of-england-told-to-stop-buying-high-carbon-bonds-idUSKBN29U01A
# 287 https://www.reuters.com/article/us-greenbonds-issuance/global-green-bond-issuance-hit-new-record-high-last-year-idUSKBN29U013
# 288 https://www.reuters.com/article/us-exxon-mobil-climate/exxon-unveils-carbon-removal-tech-venture-in-green-image-push-idUSKBN2A13S2
# 289 https://www.reuters.com/article/us-shell-strategy-insight/shell-targets-power-trading-and-hydrogen-in-climate-drive-idUSKBN2A10ZZ
# 290 https://www.reuters.com/article/us-health-coronavirus-britain-princeharr/time-to-reimagine-travel-industry-uks-prince-harry-says-idUSKBN29Y1ZM
# 291 https://www.reuters.com/article/us-gm-emissions/gm-aims-to-end-sale-of-gasoline-diesel-powered-cars-suvs-light-trucks-by-2035-idUSKBN29X2AY
# 292 https://www.reuters.com/article/us-usa-biden-climate/biden-takes-sweeping-measures-to-curb-climate-change-vows-job-creation-idUSKBN29W0YS
# 293 https://www.reuters.com/news/archive/esgnews?view=page&page=2&pageSize=10
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# /Users/osmiyg/opt/miniconda3/lib/python3.8/site-packages/bs4/builder/_htmlparser.py:102: UserWarning: expected name token at '<![0��5t�R�G㳧���VW�V'
#   warnings.warn(msg)
# cannot unpack non-iterable NoneType object
# 'HtmlDocument' object has no attribute 'content'
# 294 https://www.reuters.com/article/idUSKBN2A52JG
# 295 https://www.reuters.com/article/idUSKBN2A52SH
# 296 https://www.reuters.com/article/idUSKBN2A52S4
# 297 https://www.reuters.com/article/us-usa-economy-imf/u-s-faces-risk-of-bankruptcies-unemployment-if-fiscal-support-not-maintained-imf-idUSKBN2A52JG
# 298 https://www.reuters.com/article/us-ford-emissions/ford-says-u-s-justice-dept-california-end-probe-into-emissions-issue-idUSKBN2A527G
# 299 https://www.reuters.com/article/us-usa-harvard-lawreview/harvard-law-review-elects-first-muslim-president-idUSKBN2A52BX
# 300 https://www.reuters.com/article/us-people-nygard/canadian-judge-denies-fashion-designer-nygard-bail-in-u-s-extradition-case-idUSKBN2A5220
# 301 https://www.reuters.com/article/us-people-ghislaine-maxwell/maxwell-says-u-s-is-prosecuting-her-only-because-jeffrey-epstein-is-dead-idUSKBN2A529J
# 302 https://www.reuters.com/article/us-amazon-com-labor/u-s-labor-board-denies-amazons-request-to-halt-alabama-union-election-idUSKBN2A51ZX
# 303 https://www.reuters.com/article/us-retail-trading-gamestop-investors/to-the-moon-or-to-a-lawyer-gamestop-investors-cope-with-stocks-rollercoaster-idUSKBN2A510U
# 304 https://www.reuters.com/article/us-clover-health-short-seller/clover-health-shares-rebound-after-palihapitiya-comments-on-negative-report-idUSKBN2A518S
# 305 https://www.reuters.com/news/archive/westLaw
# 306 https://www.reuters.com/article/employment-amazon/nlrb-cites-warehouse-outbreak-local-covid-rate-in-denying-in-person-election-to-amazon-idUSL1N2KB3C0
# 307 https://www.reuters.com/article/bankruptcy-boy-scouts/boy-scouts-sex-abuse-survivors-group-accuses-insurers-of-ugly-games-idUSL1N2KB3BY
# 308 https://www.reuters.com/article/health-astellas/astellas-prevails-over-imstem-in-stem-cell-inventorship-fight-idUSL1N2KB3C3
# 309 https://www.reuters.com/article/us-global-oil/oil-rises-1-hits-highest-in-a-year-on-growth-hopes-opec-output-cuts-idUSKBN2A508I
# 310 https://www.reuters.com/article/us-russia-nordstream2-gas-pipes/pipe-laying-for-nord-stream-2-restarts-in-danish-waters-idUSKBN2A60OT
# 311 https://www.reuters.com/article/us-global-oil-opec-graphic/brent-near-60-as-opec-cuts-tighten-oil-market-idUSKBN2A51L9
# 312 https://www.reuters.com/article/us-usa-rigs-baker-hughes/u-s-drillers-add-oil-and-gas-rigs-for-11th-week-in-a-row-baker-hughes-idUSKBN2A52BG
# 313 https://www.reuters.com/article/us-occidental-petroleum-blackrock/asset-manager-blackrock-cuts-stake-in-occidental-petroleum-idUSKBN2A52L7
# 314 https://www.reuters.com/article/us-global-oil-kemp/column-escalating-oil-prices-signal-need-for-more-output-idUSKBN2A42K9
# 315 https://www.reuters.com/article/us-shell-results/shells-profit-slumps-in-2020-as-the-pandemic-bites-idUSKBN2A40RT
# 316 https://www.reuters.com/article/us-mining-indigenous-australia/rio-tinto-board-could-face-pressure-on-indigenous-broken-promise-claim-idUSKBN2A40GU
# 317 https://www.reuters.com/article/us-liberty-oilfield-results/liberty-oilfield-posts-smaller-than-expected-loss-sees-tepid-recovery-idUSKBN2A42YD
# 318 https://www.reuters.com/news/archive/rcomus_energy?view=page&page=2&pageSize=10
# 319 https://www.reuters.com/video/2021/02/05/gamestop-shares-jump-after-robinhood-lif?videoId=725400550&videoChannel=5
# 320 https://www.reuters.com/video/2021/02/05/no-roof-for-a-solar-panel-buy-one-at-a-p?videoId=725395669&videoChannel=5
# 321 https://www.reuters.com/article/us-europe-weather-germany/snow-dump-puts-northern-germany-in-deep-freeze-idUSKBN2A70DJ
# 322 https://www.reuters.com/article/us-indonesia-environment/indonesian-village-turns-red-as-floods-hit-batik-manufacturing-hub-idUSKBN2A60AQ
# 323 https://www.reuters.com/article/us-un-climate-bloomberg/u-n-chief-names-michael-bloomberg-climate-envoy-to-rally-action-idUSKBN2A516B
# 324 https://www.reuters.com/article/us-europe-regulations-finance/eu-sustainable-finance-rules-delayed-by-gas-and-biofuel-backlash-idUSKBN2A51VM
# 325 https://www.reuters.com/news/archive/environmentnews?view=page&page=2&pageSize=10
# 326 https://www.reuters.com/article/us-usa-economy/subsiding-layoffs-raise-cautious-optimism-for-u-s-labor-market-idUSKBN2A41TN
# 327 https://www.reuters.com/article/us-deutsche-bank-results/investment-banking-boom-lands-deutsche-bank-first-profit-since-2014-idUSKBN2A40OD
# 328 https://www.reuters.com/article/us-commerzbank-strategy/commerzbank-ceo-finalizes-plans-to-cut-10000-jobs-close-branches-idUSKBN2A330E
# 329 https://www.reuters.com/article/us-citigroup-ceo/citis-incoming-ceo-fraser-forms-new-operating-team-to-build-leadership-accountability-idUSKBN2A3056
# 330 https://www.reuters.com/article/us-hsbc-hldg-wealth-thailand/hsbc-sets-up-private-banking-business-in-thailand-second-in-southeast-asia-idUSKBN2A11P8
# 331 https://www.reuters.com/article/us-wells-fargo-ceo-compensation/wells-fargo-ceo-scharfs-pay-drops-nearly-12-in-2020-idUSKBN29Y312
# 332 https://www.reuters.com/article/us-retail-trading-robinhood/robinhood-raises-1-billion-of-fresh-funding-from-existing-investors-idUSKBN29X2ZN
# 333 https://www.reuters.com/article/us-deutsche-bank-ceo-exclusive/exclusive-regulators-press-deutsche-bank-ceo-to-drop-investment-bank-role-sources-idUSKBN29X10L
# 334 https://www.reuters.com/article/us-jpmorgan-digital-uk/jpmorgan-to-join-british-online-banking-chase-within-months-idUSKBN29W1DE
# 335 https://www.reuters.com/news/archive/bank-news?view=page&page=2&pageSize=10
# 336 https://www.reuters.com/article/us-congo-security/suspected-islamists-kill-10-in-eastern-congo-machete-attack-idUSKBN2A70EX
# 337 https://www.reuters.com/article/us-gulf-qatar-egypt/egypt-frees-al-jazeera-journalist-after-four-years-in-detention-idUSKBN2A7086
# 338 https://www.reuters.com/article/us-india-twitter/playing-with-fire-twitters-india-snub-sparks-debate-on-compliance-free-speech-idUSKBN2A60DO
# 339 https://www.reuters.com/article/us-fox-lou-dobbs/fox-cancels-lou-dobbs-weekday-show-on-fox-business-network-idUSKBN2A601G
# 340 https://www.reuters.com/article/us-people-christopher-plummer-quotes/reaction-to-the-death-of-actor-christopher-plummer-idUSKBN2A52LQ
# 341 https://www.reuters.com/article/us-svf-investment-corp-2-ipo/softbank-looks-to-raise-about-550-million-through-two-more-spacs-idUSKBN2A52SM
# 342 https://www.reuters.com/article/us-netflix-obamas/sci-fi-films-young-adult-thriller-among-six-new-obama-projects-for-netflix-idUSKBN2A52AJ
# 343 https://www.reuters.com/article/us-russia-politics-navalny-protesters/protest-portraits-the-russians-rallying-behind-kremlin-critic-navalny-idUSKBN2A51R3
# 344 https://www.reuters.com/article/us-australia-media-google/google-opens-paid-for-australia-news-platform-in-drive-to-undercut-canberras-content-payment-law-idUSKBN2A50FB
# 345 https://www.reuters.com/article/us-television-snoopy/good-grief-snoopy-brings-new-antics-to-peanuts-streaming-series-idUSKBN2A51V8
# 346 https://www.reuters.com/news/archive/rcom-media-telecoms?view=page&page=2&pageSize=10
# 347 https://www.reuters.com/article/us-health-coronavirus-britain-passport/britain-will-not-introduce-covid-19-vaccine-passports-idUSKBN2A7097
# 348 https://www.reuters.com/article/us-health-coronavirus-australia/australia-reports-no-new-local-coronavirus-cases-ahead-of-australian-open-idUSKBN2A703C
# 349 https://www.reuters.com/news/archive/healthnews?view=page&page=2&pageSize=10
# 350 https://www.reuters.com/video/2018/07/09/arkansans-fear-losing-medicaid-with-new?videoId=443898507&videoChannel=118164
# 351 https://www.reuters.com/article/us-stellantis-italy-bonus/stellantis-to-pay-bigger-efficiency-bonus-to-italian-workers-unions-idUSKBN2A5240
# 352 https://www.reuters.com/article/us-signature-aviation-m-a-brown/signature-aviation-dog-fight-ends-as-gip-bids-with-blackstone-and-cascade-idUSKBN2A50PN
# 353 https://www.reuters.com/article/us-taiwan-usa-trade/taiwan-says-u-s-thanks-it-for-help-on-auto-chips-amid-shortage-idUSKBN2A50DC
# 354 https://www.reuters.com/article/us-indonesia-nickel-tesla/indonesia-receives-investment-proposal-from-tesla-official-idUSKBN2A50C5
# 355 https://www.reuters.com/article/us-ford-motor-results/ford-boosts-investment-plan-for-evs-and-self-driving-vehicles-reports-loss-idUSKBN2A42VN
# 356 https://www.reuters.com/article/us-usa-ford-semiconductors/ford-cuts-output-of-f-150-pickups-due-to-semiconductor-shortage-idUSKBN2A42G3
# 357 https://www.reuters.com/article/us-volkswagen-chips-audi/hit-by-shortage-volkswagen-demands-boost-to-europe-chip-sector-idUSKBN2A41RS
# 358 https://www.reuters.com/article/us-autos-europe-electric/eu-electric-and-plug-in-hybrid-car-sales-jump-to-over-1-million-in-2020-idUSKBN2A41HR
# 359 https://www.reuters.com/article/us-mazda-semiconductors/mazda-expects-chip-shortage-to-affect-about-7000-vehicles-in-february-idUSKBN2A40WO
# 360 https://www.reuters.com/article/us-american-airline-jobs/american-airlines-sending-13000-furlough-warnings-as-pandemic-pain-persists-idUSKBN2A3371
# 361 https://www.reuters.com/article/us-fordmotor-china-zotye/ford-motor-terminates-electric-vehicle-plans-with-chinas-zotye-idUSKBN2A409A
# 362 https://www.reuters.com/article/us-ford-motor-results-preview/fords-forecast-in-focus-as-it-wraps-up-year-with-quarterly-loss-idUSKBN2A32YE
# 363 https://www.reuters.com/article/us-daimler-trucks-divestiture/daimler-to-spin-off-truck-unit-sharpen-investor-focus-on-mercedes-benz-idUSKBN2A329T
# 364 https://www.reuters.com/article/us-gm-semiconductors-exclusive/gm-hit-by-chip-shortage-to-cut-production-at-four-plants-idUSKBN2A32LL
# 365 https://www.reuters.com/article/us-autos-chips/chip-crunch-to-impact-global-auto-production-into-third-quarter-says-ihs-idUSKBN2A32DU
# 366 https://www.reuters.com/article/us-auto-tech-apple-kia/south-korea-carmaker-kias-shares-jump-14-5-on-apple-ev-tie-up-report-idUSKBN2A30HS
# 367 https://www.reuters.com/article/us-germany-autos/german-car-sales-drop-30-in-january-source-idUSKBN2A31AC
# 368 https://www.reuters.com/news/archive/autos-upclose?view=page&page=2&pageSize=10
# 369 https://www.reuters.com/article/us-health-coronavirus-airlines-summer/airlines-flying-blind-into-summer-capacity-sweepstake-idUSKBN2A21S5
# 370 https://www.reuters.com/article/us-harley-davidson-results/harley-unveils-turnaround-plan-as-shares-nosedive-on-disappointing-results-idUSKBN2A21C0
# 371 https://www.reuters.com/article/us-tesla-recall/tesla-to-recall-135000-u-s-vehicles-under-pressure-from-auto-safety-regulators-idUSKBN2A21FC
# 372 https://www.reuters.com/article/us-ryanair-results/ryanair-predicts-strong-recovery-after-record-annual-loss-idUSKBN2A11F6
# 373 https://www.reuters.com/article/us-china-hna-bankruptcy/chinas-hna-eyes-private-investors-in-uphill-battle-to-emerge-from-bankruptcy-idUSKBN2A116W
# 374 https://www.reuters.com/article/us-trade-wto-southkorea/nigerian-woman-poised-to-lead-wto-after-rival-withdraws-washington-offers-support-idUSKBN2A52RD
# 375 https://www.reuters.com/article/us-maryland-security-andrews/u-s-air-force-to-review-global-base-security-after-intrusion-at-home-of-air-force-one-idUSKBN2A51MS
# 376 https://www.reuters.com/article/us-china-usa-taiwan/china-says-u-s-creating-tensions-after-warship-sails-near-taiwan-idUSKBN2A500N
# 377 https://www.reuters.com/article/us-rolls-royce-hldg-disposal/rolls-royce-disposal-plan-banks-150-million-euros-from-bergen-engines-sale-idUSKBN2A41AT
# 378 https://www.reuters.com/article/us-emirates-defense-politics/uae-u-s-foreign-ministers-discuss-strategic-relations-uae-foreign-ministry-idUSD5N2HK029
# 379 https://www.reuters.com/news/archive/aerospace-defense?view=page&page=2&pageSize=10
# 380 https://www.reuters.com/video/2018/07/18/why-your-plane-might-be-hackers-next-tar?videoId=446527693&videoChannel=118264
# 381 https://www.reuters.com/video/2018/07/17/rising-oil-price-spurs-jet-buying-bonanz?videoId=446212418&videoChannel=118264
# 382 https://www.reuters.com/video/2018/07/16/qatar-airways-ceo-shrugs-off-blockade-co?videoId=445921270&videoChannel=118264
# 383 https://www.reuters.com/article/us-change-suite-coursera/course-to-success-courseras-ceo-on-the-value-of-lifelong-learning-idUSKBN2A50ET
# 384 https://www.reuters.com/article/us-merck-co-ceo/one-of-the-few-top-u-s-black-ceos-mercks-ken-frazier-to-retire-idUSKBN2A41ML
# 385 https://www.reuters.com/article/us-change-suite-managingup/managing-your-boss-adjusting-to-narcissists-ghosts-gaslighters-idUSKBN2A40HC
# 386 https://www.reuters.com/article/us-amazon-com-bezos/with-bezos-out-as-amazon-ceo-is-this-the-end-of-his-ominous-question-mark-emails-idUSKBN2A32Z8
# 387 https://www.reuters.com/article/us-amazon-com-results/bezos-to-give-amazon-reins-to-cloud-boss-jassy-as-sales-rocket-past-100-billion-idUSKBN2A22UH
# 388 https://www.reuters.com/article/us-amazon-com-results-research/bezos-shock-exit-cools-amazon-results-boost-idUSKBN2A31U2
# 389 https://www.reuters.com/article/us-amazon-com-whole-foods-race-lawsuit/judge-rejects-whole-foods-employees-claims-over-black-lives-matter-face-masks-idUSKBN2A52HY
# 390 https://www.reuters.com/article/us-usa-results-s-p500/u-s-companies-set-to-post-profit-growth-for-q4-which-would-defy-forecasts-idUSKBN2A32K0
# 391 https://www.reuters.com/article/us-usa-trade-eu/white-house-says-european-trade-tariff-policy-under-review-idUSKBN2A52FX
# 392 https://www.reuters.com/article/us-autos-semiconductors-europe/renault-and-stellantis-cut-some-production-as-chip-shortages-bite-idUSKBN2A52AD
# ...
# 811 https://www.reuters.com/article/us-motor-f1-domenicali/domenicali-says-f1-could-reduce-and-rotate-races-in-future-idUSKBN29P2I8
# 812 https://www.reuters.com/article/us-motor-f1-korea-aitken/aitken-hopes-to-put-south-korea-back-on-formula-one-map-idUSKBN29F06Z
# 813 https://www.reuters.com/news/archive/football-nfl
# 814 https://www.reuters.com/article/us-football-nfl-superbowl-bucs-superfan/were-about-to-become-title-town-says-lifelong-tampa-bay-super-fan-idUSKBN2A60RT
# 815 https://www.reuters.com/article/football-nfl-superbowl-masks/mask-wearing-slips-in-tampa-as-fans-celebrate-super-bowl-weekend-idUSL1N2KD002
# 816 https://www.reuters.com/article/us-football-nfl-kc-kilgore/reports-chiefs-center-daniel-kilgore-cleared-for-super-bowl-idUSKBN2A7004
# 817 https://www.reuters.com/news/archive/sport-cricket
# 818 https://www.reuters.com/article/us-cricket-usa-league/ipls-knight-riders-buy-stake-in-u-s-based-major-league-cricket-idUSKBN28B5FM
# 819 https://www.reuters.com/article/us-cricket-usa/usa-cricket-eyes-full-icc-membership-by-2030-idUSKBN2710QN
# 820 https://www.reuters.com/article/us-cricket-zaf/south-africa-wait-on-selection-convenor-to-make-test-captain-choice-idUSKCN26C1EC
# 821 https://www.reuters.com/news/archive/sport-sailing
# 822 https://www.reuters.com/article/us-hungary-sailing-family/splendid-isolation-hungarian-family-outsails-covid-nightmare-on-the-sea-idUSKBN2A1288
# 823 https://www.reuters.com/article/hungary-sailing-family/splendid-isolation-hungarian-family-outsails-covid-nightmare-on-the-sea-idUSL8N2K60EK
# 824 https://www.reuters.com/article/us-sailing-americascup/luna-rossas-spithill-calls-for-improvements-ahead-of-ineos-showdown-idUSKBN2A0051
# 825 https://www.reuters.com/article/us-silver-lake-new-zealand-rugby/silver-lake-in-talks-for-stake-in-new-zealands-all-blacks-source-idUSKBN29H05T
# 826 https://www.reuters.com/article/us-sport-yearender-rugby/rugby-concussion-case-casts-dark-cloud-over-the-sport-idUSKBN28S07V
# 827 https://www.reuters.com/article/us-rugby-union-championship-aus-arg/student-sings-australian-national-anthem-in-indigenous-language-before-rugby-match-idUSKBN28F0HO
# 828 https://www.reuters.com/news/archive/sport-athletics
# 829 https://www.reuters.com/article/us-athletics-doping-kibet/kenyas-kibet-gets-four-year-ban-for-violating-anti-doping-rules-idUSKBN2A51O6
# 830 https://www.reuters.com/article/athletics-britain-johnson-thompson/athletics-injured-heptathlon-champion-johnson-thompson-out-until-march-idUSL4N2K71WF
# 831 https://www.reuters.com/article/us-athletics-smith/athletics-raised-fist-olympian-smith-to-grace-cover-of-wheaties-box-idUSKBN29Y32B
# 'HtmlDocument' object has no attribute 'content'
# 832 https://www.reuters.com/article/us-health-coronavirus-science/new-darpin-drugs-show-promise-good-cholesterol-tied-to-lower-risk-idUSKBN2A52L3
# 833 https://www.reuters.com/article/us-health-coronavirus-science/covid-19-also-attacks-the-pancreas-one-vaccine-dose-may-be-enough-for-those-previously-infected-idUSKBN2A332Q
# 834 https://www.reuters.com/article/us-germany-chameleon/this-newly-discovered-chameleon-is-so-tiny-it-can-fit-on-your-fingertip-idUSKBN2A42C4
# 835 https://www.reuters.com/article/us-space-exploration-starship/spacex-starship-prototype-rocket-explodes-on-landing-after-test-launch-idUSKBN2A22SX
# 836 https://www.reuters.com/article/us-tech-robots-boston-dynamics-spot/robotic-dog-spot-learns-new-tricks-with-addition-of-helping-hand-idUSKBN2A22PD
# 837 https://www.reuters.com/article/us-health-coronavirus-science/some-lingering-covid-19-issues-seen-in-children-patients-antibodies-attack-multiple-virus-targets-idUSKBN2A13I6
# 838 https://www.reuters.com/article/us-space-exploration-starship/musks-spacex-violated-its-launch-license-in-explosive-starship-test-the-verge-idUSKBN29Z06R
# 839 https://www.reuters.com/article/us-health-coronavirus-science/jj-vaccine-effective-in-preventing-severe-disease-a-mothers-covid-19-antibodies-may-protect-newborns-idUSKBN29Y2PF
# 840 https://www.reuters.com/news/archive/sciencenews?view=page&page=2&pageSize=10
# 841 https://www.reuters.com/article/us-ubs-investment-banking-bonus/ubs-to-lift-investment-bank-bonus-pool-by-20-bloomberg-news-idUSKBN2A600H
# 842 https://www.reuters.com/finance/investing
# 843 https://www.reuters.com/news/archive/wealth-taxes
# 844 https://www.reuters.com/news/archive/wealth-family
# 845 https://www.reuters.com/article/us-change-suite-scrivner/starting-a-job-dream-big-and-dont-be-afraid-to-fail-says-wella-ceo-idUSKBN29B0FQ
# 846 https://www.reuters.com/article/us-usa-economy-savings/low-income-u-s-households-are-spending-savings-quicker-than-high-earners-study-idUSKBN28Q0IX
# 847 https://www.reuters.com/article/change-suite-vmware/trust-equity-and-sustainability-vmwares-gelsinger-on-a-2030-agenda-idUSKBN28K1N6
# 848 https://www.reuters.com/news/archive/wealth-retirement
# 849 https://www.reuters.com/article/us-new-york-murder-housing/man-accused-of-murdering-nyc-elderly-housing-residents-due-in-court-idUSKBN29R25Q
# 850 https://www.reuters.com/article/us-health-coronavirus-serbia-vaccine/serbia-becomes-first-european-country-to-use-chinese-covid-vaccine-for-mass-rollout-idUSKBN29O1M5
# 851 https://www.reuters.com/video/2021/02/05/sp-nasdaq-post-best-weekly-gains-in-thre?videoId=725411483&videoChannel=303
# 852 https://www.reuters.com/video/2021/02/05/big-correction-could-come-in-spring-geor?videoId=725408899&videoChannel=303
# 853 https://www.reuters.com/video/2021/02/05/gamestop-shares-jump-after-robinhood-lif?videoId=725400550&videoChannel=303
# 854 https://www.reuters.com/article/us-prudential-finl-results-life-insuranc/prudential-ceo-mulls-shrinking-life-insurance-low-growth-businesses-idUSKBN2A52ED
# 855 https://www.reuters.com/article/us-markets-flows-bofa/big-wall-st-investors-chased-tech-during-gamestop-retail-frenzy-bofa-idUSKBN2A50TU
# 856 https://www.reuters.com/article/us-bank-of-america-mortgage/bank-of-america-triples-affordable-housing-commitment-idUSKBN2A3203
# 857 https://www.reuters.com/article/us-usa-investments-mutualfunds/u-s-stock-funds-post-biggest-weekly-outflow-since-september-lipper-idUSKBN2A42UF
# 858 https://www.reuters.com/article/us-hedgefunds-returns/hot-ticket-gamestop-deals-blow-to-hedge-funds-january-returns-some-escape-idUSKBN2A22U8
# 859 https://www.reuters.com/article/us-clover-health-short-seller/palihapitiya-backed-clover-health-plunges-after-short-seller-hindenburg-weighs-in-idUSKBN2A41U7
# 860 https://www.reuters.com/article/us-gamestop-funds-graphic/performance-of-funds-invested-in-gamestop-in-past-two-weeks-idUSKBN2A50ZN
# 861 https://www.reuters.com/article/us-global-wealth-column/column-basking-in-pseudo-wealth-idUSKBN2A30SU
# 862 https://www.reuters.com/article/us-canada-hedgefunds/hedge-funds-bet-rally-in-canadian-silver-mining-stocks-to-run-out-of-steam-idUSKBN2A20LV
# 863 https://www.reuters.com/news/archive/personalfinance?view=page&page=2&pageSize=10
# 864 https://www.reuters.com/subjects/life-lessons
# 865 https://www.reuters.com/article/us-money-lifelessons-bellamyyoung/presidential-material-life-lessons-with-bellamy-young-idUSKBN1YL253
# 866 https://www.reuters.com/article/us-money-lifelessons-harrisrosen/local-hero-florida-hotelier-harris-rosen-keeps-his-giving-close-to-home-idUSKBN1Y01VY
# 867 https://www.reuters.com/article/us-money-lifelessons-brookeshields/a-model-life-life-lessons-with-brooke-shields-idUSKBN1W91C0
# 868 https://www.reuters.com/article/us-crypto-currency-germany-password/police-seize-60-million-of-bitcoin-now-wheres-the-password-idUSKBN2A511T
# 869 https://www.reuters.com/article/us-health-coronavirus-germany-sniffer-do/german-sniffer-dogs-detect-covid-19-with-94-accuracy-idUSKBN2A32Q4
# 870 https://www.reuters.com/article/us-france-macron-umbrella/frances-macron-i-will-not-surrender-my-umbrella-idUSKBN2A322W
# 871 https://www.reuters.com/article/us-health-coronavirus-belgium-restaurant/missing-customers-belgian-restaurateur-serves-mannequins-idUSKBN2A21YB
# 872 https://www.reuters.com/article/us-football-nfl-superbowl-dolphin/nfl-rescued-dolphin-picks-chiefs-to-win-super-bowl-idUSKBN2A22VD
# 873 https://www.reuters.com/article/us-basketball-nba-atl-lal/lakers-james-plays-down-row-with-spectators-in-win-over-hawks-idUSKBN2A20YI
# 874 https://www.reuters.com/news/archive/oddlyenoughnews?view=page&page=2&pageSize=10
# 875 https://www.reuters.com/article/pictures-report/photos-of-the-week-idUSRTX8YPRQ
# 876 https://www.reuters.com/news/picture/protests-against-military-coup-spread-ac-idUSRTR4Z5HC
# 877 https://www.reuters.com/news/picture/tiny-patients-fight-covid-in-mexico-neon-idUSRTR4Z5HU
# 878 https://www.reuters.com/news/picture/classic-super-bowl-moments-idUSRTX8YI79
# 879 https://www.reuters.com/news/picture/notable-deaths-in-2021-idUSRTR4Z4Y0
# 880 https://www.reuters.com/news/picture/memorable-super-bowl-halftime-shows-idUSRTX8YGJG
# 881 https://www.reuters.com/news/picture/thai-shelter-for-disabled-stray-dogs-thr-idUSRTX8XTG1
# 882 https://www.reuters.com/news/picture/photos-of-the-week-idUSRTR4Z5F5
# 883 https://www.reuters.com/news/picture/pandemic-upends-life-for-irish-pub-owner-idUSRTR4Z5HM
# 884 https://www.reuters.com/news/pictures/archive?page=2&pageSize=9
# 885 https://www.reuters.com/video/2021/02/01/images-of-january?videoId=725142268&videoChannel=118069
# 886 https://www.reuters.com/video/2021/01/01/images-of-december?videoId=723661595&videoChannel=118069
# 887 https://www.reuters.com/video/2020/12/16/reuters-pictures-of-the-year-2020?videoId=723120841&videoChannel=118069
# 888 https://www.reuters.com/video/breakingviews
# 889 https://www.reuters.com/video/business
# 890 https://www.reuters.com/video/marketsnow
# 891 https://www.reuters.com/video/great-reboot
# 892 https://www.reuters.com/video/change-suite
# 893 https://www.reuters.com/video/sectors-upclose
# 894 https://www.reuters.com/video?feat=1WgdzxmbJQ4M
# 895 https://www.reuters.com/video/technology
# 896 https://www.reuters.com/video/world
# 897 https://www.reuters.com/video/entertainment
# 898 https://www.reuters.com/video/politics
# 899 https://www.reuters.com/video/oddly-enough
# 900 https://www.reuters.com/news/archive/rcom-media-telecoms
# 901 https://www.reuters.com/news/archive/APAC
# 902 https://www.reuters.com/news/picture/britain-mourns-pandemic-hero-captain-tom-idUSRTR4Z5D1
# 'HtmlDocument' object has no attribute 'content'
# 903 https://www.reuters.com/news/archive/reboot-live
# 904 https://www.reuters.com/news/archive/bank-news
# 905 https://www.reuters.com/journalists/maiya-keidan
# 906 https://www.reuters.com/journalists/rod-nickel
# 907 https://www.reuters.com/news/archive/innovationNewsTechMediaTelco
# 908 https://www.reuters.com/news/archive/environmentNews
# 909 https://www.reuters.com/journalists/devjyot-ghoshal
# 910 https://www.reuters.com/journalists/manoj-kumar
# 911 https://www.reuters.com/article/us-swiss-eu/eu-ambassador-to-switzerland-says-treaty-talks-finished-blick-idUSKBN2A70DF
# 912 https://www.reuters.com/news/archive/us-the-wire?view=page&page=2&pageSize=10
# 913 https://www.reuters.com/news/archive/coronavirus-cure
# 914 https://www.reuters.com/journalists/alexandra-valencia
# 915 https://www.reuters.com/journalists/brian-ellsworth
# 916 https://www.reuters.com/news/archive/rcom-apac
# 917 https://www.reuters.com/news/archive/retail
# 918 https://www.reuters.com/news/archive/RCOMUS_Brexit
# 919 https://www.reuters.com/news/archive/rcom-eur-markets
# 920 https://www.reuters.com/news/archive/rcom-emerging-markets
# 921 https://www.reuters.com/journalists/corinna-kern
# 922 https://www.reuters.com/news/archive/newsMaps
# 923 https://www.reuters.com/news/archive/healthNews
# 924 https://www.reuters.com/journalists/sanjeev-miglani
# 925 https://www.reuters.com/news/archive/BigStory12
# 926 https://www.reuters.com/journalists/philip-pullella
# 927 https://www.reuters.com/journalists/costas-pitas
# 928 https://www.reuters.com/journalists/ruma-paul
# 929 https://www.reuters.com/news/archive/sportsNews
# 930 https://www.reuters.com/journalists/amy-tennery
# 931 https://www.reuters.com/journalists/rory-carroll
# 932 https://www.reuters.com/journalists/gabriella-borter
# 933 https://www.reuters.com/journalists/nathan-frandino
# 934 https://www.reuters.com/news/archive/greatreboot
# 935 https://www.reuters.com/journalists/timothy-aeppel
# 936 https://www.reuters.com/journalists/gavin-jones
# 937 https://www.reuters.com/journalists/emma-thomasson
# 938 https://www.reuters.com/news/archive/aerospace-defense
# 939 https://www.reuters.com/journalists/parisa-hafezi
# 940 https://www.reuters.com/news/archive/esg-environment
# 941 https://www.reuters.com/news/archive/americas-test-2
# 942 https://www.reuters.com/news/archive/media-industry
# 'HtmlDocument' object has no attribute 'content'
# 943 https://www.reuters.com/news/picture/top-photos-of-the-day-idUSRTX8Y855
# 944 https://www.reuters.com/news/picture/top-photos-of-the-day-idUSRTX8X8RE
# 945 https://www.reuters.com/news/picture/top-photos-of-the-day-idUSRTX8VXHY
# 946 https://www.reuters.com/news/picture/top-photos-of-the-day-idUSRTX8UCO1
# 947 https://www.reuters.com/news/archive/innovationNewsIndustryMaterialsAndUtilities
# 948 https://www.reuters.com/news/archive/businessNews
# 949 https://www.reuters.com/journalists/kate-duguid
# 950 https://www.reuters.com/journalists/matt-scuffham
# 951 https://www.reuters.com/news/archive/GCA-ForeignExchange
# 952 https://www.reuters.com/news/archive/ousivMolt
# 953 https://www.reuters.com/news/archive/technologyNews
# 954 https://www.reuters.com/journalists/cate-cadell
# 955 https://www.reuters.com/journalists/pei-li
# 956 https://www.reuters.com/journalists/david-shepardson
# 957 https://www.reuters.com/article/us-gamestop-stocks-shortinterest/numbers-of-gamestop-shares-shorted-dips-further-s3-partners-idUSKBN2A51YX
# 958 https://www.reuters.com/journalists/susan-cornwell
# 959 https://www.reuters.com/journalists/richard-cowan
# 960 https://www.reuters.com/news/archive/USLegal
# 961 https://www.reuters.com/news/archive/meaNews
# 962 https://www.reuters.com/journalists/ted-hesson
# 963 https://www.reuters.com/journalists/mimi-dwyer
# 964 https://www.reuters.com/news/archive/autos-upclose
# 965 https://www.reuters.com/news/archive/innovationNews
# 'HtmlDocument' object has no attribute 'content'
# 'HtmlDocument' object has no attribute 'content'
# 966 https://www.reuters.com/news/archive/BigStory10
# 967 https://www.reuters.com/article/uk-factcheck-pelosi-2017-video-misleadin/fact-check-2017-video-shows-nancy-pelosi-talking-about-republicans-using-wrap-up-smear-tactic-idUSKBN2A52UB
# 968 https://www.reuters.com/article/uk-factcheck-photo-wisconsin-not-kavanau/fact-check-photo-shows-2011-wisconsin-protest-not-kavanaughs-confirmation-hearing-idUSKBN2A52PT
# 969 https://www.reuters.com/article/uk-factcheck-mandatory-mask-war-crime/fact-check-mandatory-mask-wearing-is-not-a-war-crime-that-violates-the-nuremberg-code-idUSKBN2A52OU
# 970 https://www.reuters.com/article/uk-factcheck-vaccine-death/fact-check-captain-tom-did-not-receive-and-was-not-killed-by-the-coronavirus-vaccine-idUSKBN2A52KP
# 971 https://www.reuters.com/article/uk-factcheck-government-letter/fact-check-fake-uk-government-letter-about-deliberately-damaging-the-economy-via-the-pandemic-idUSKBN2A529H
# 972 https://www.reuters.com/article/uk-factcheck-greta/fact-check-greta-thunberg-has-not-been-arrested-or-charged-by-indian-police-for-tweeting-about-a-protest-idUSKBN2A5249
# 973 https://www.reuters.com/article/uk-factcheck-led-sign/fact-check-vaccines-aretested-and-covid-19-is-a-real-disease-idUSKBN2A52D6
# 974 https://www.reuters.com/article/uk-factcheck-alzheimers-risk-image-camel/fact-check-no-evidence-linking-spot-the-camel-and-alzheimers-risk-idUSKBN2A5256
# 975 https://www.reuters.com/article/uk-factcheck-hancock/fact-check-uk-government-did-not-suggest-covid-19-vaccines-are-pointless-idUSKBN2A52GB
# 976 https://www.reuters.com/article/uk-factcheck-aoc-instagram-live-video/fact-check-alexandria-ocasio-cortez-did-not-claim-that-she-was-in-the-capitol-during-siege-nor-that-rioters-entered-her-office-idUSKBN2A51RK
# 977 https://www.reuters.com/news/archive/reuterscomservice?view=page&page=2&pageSize=10
# 'HtmlDocument' object has no attribute 'content'

# %% [markdown]
# ### 1.2.5. [5] Index statistics
#
# Load an index and print the statistics.

# %%
# load index, doc_lengths and doc_urls
with open('inverted_index.p', 'rb') as fp:
    index = pickle.load(fp)
with open('doc_lengths.p', 'rb') as fp:
    doc_lengths = pickle.load(fp)
with open('doc_urls.p', 'rb') as fp:
    doc_urls = pickle.load(fp)
    
    
print('Total index length', len(index))
print('\nTop terms by number of documents they apperared in:')
sorted_by_n_docs = sorted(index.items(), key=lambda kv: (len(kv[1]), kv[0]), reverse=True)
print([(sorted_by_n_docs[i][0], len(sorted_by_n_docs[i][1])) for i in range(20)])
print('\nTop terms by overall frequency:')
sorted_by_freq = sorted(index.items(), key=lambda kv: (kv[1][0], kv[0]), reverse=True)
print([(sorted_by_freq[i][0], sorted_by_freq[i][1][0]) for i in range(20)])
# Out:
# Total index length 14247
#
# Top terms by number of documents they apperared in:
# [('use', 978), ('term', 978), ('privaci', 978), ('reuter', 977), ('not', 948), ('see', 947), ('all', 947), ('do', 945), ('here', 944), ('us', 942), ('my', 942), ('person', 938), ('list', 938), ('inform', 938), ('exchang', 938), ('site', 937), ('sell', 935), ('minut', 933), ('delay', 933), ('app', 933)]
#
# Top terms by overall frequency:
# [('reuter', 6613), ('s', 3969), ('said', 2961), ('market', 2831), ('all', 2805), ('us', 2231), ('delay', 2180), ('news', 2093), ('not', 2084), ('more', 2073), ('advertis', 2008), ('thomson', 1920), ('minut', 1909), ('new', 1868), ('after', 1827), ('busi', 1782), ('follow', 1650), ('world', 1583), ('inform', 1532), ('biden', 1484)]

# %% [markdown]
# ## 1.3. [15] Answering query
#
# Now, given that we already have built the inverted index, it's time to utilize it for answering user queries. In this class there are two methods you need to implement:
# - `boolean_retrieval`, the simplest form of document retrieval which returns a set of documents such that each one contains all query terms. Returns a set of document ids. Refer to *ch.1* of the book for details;
# - `okapi_scoring`, Okapi BM25 ranking function - assigns scores to documents in the collection that are relevant to the user query. Returns a dictionary of scores, `doc_id:score`. Read about it in [Wikipedia](https://en.wikipedia.org/wiki/Okapi_BM25#The_ranking_function) and implement accordingly.
#
# Both methods accept `query` parameter in a form of a dictionary, `term:frequency`

# %%
from collections import Counter
import math

class QueryProcessing:
    
    @staticmethod
    def prepare_query(raw_query):
        prep = Preprocessor()
        # pre-process query the same way as documents
        query = prep.preprocess(raw_query)
        # count frequency
        return Counter(query)
    
    @staticmethod
    def boolean_retrieval(query, index):
        #TODO retrieve a set of documents containing all query terms
        set_docs = None
        for word in query:
            if set_docs:
                set_docs = set_docs.intersection(set([x[0] for x in index[word][1:]]))
            else:
                set_docs = set([x[0] for x in index[word][1:]])
        
        return set_docs

    
    @staticmethod
    def okapi_scoring(query, doc_lengths, index, k1=1.2, b=0.75):
        #TODO retrieve relevant documents with scores
        scores = dict()
        for doc in doc_lengths.keys():
            scores[doc] = 0

        avg = sum(doc_lengths.values()) / len(doc_lengths)

        for word, query_freq in query.items():
            if word not in index:
                continue
            idf = math.log10(len(doc_lengths) / len(index[word][1:]))

            for doc, dtf in index[word][1:]:
                if doc in scores:
                    scores[doc] += idf * dtf * (k1 + 1) / (dtf + k1 * (1 - b + b * doc_lengths[doc] / avg))
        scores = dict([(doc, score) for doc, score in scores.items() if score > 0])
        return scores

# %% [markdown]
# ### 1.3.1. Tests

# %%
test_doc_lengths = {1: 20, 2: 15, 3: 10, 4:20, 5:30}
test_index = {'x': [2, (1, 1), (2, 1)], 'y': [2, (1, 1), (3, 1)], 'z': [3, (2, 1), (4,2)]}


test_query1 = QueryProcessing.prepare_query('x z')
test_query2 = QueryProcessing.prepare_query('x y')


assert QueryProcessing.boolean_retrieval(test_query1, test_index) == {2}
assert QueryProcessing.boolean_retrieval(test_query2, test_index) == {1}
okapi_res = QueryProcessing.okapi_scoring(test_query2, test_doc_lengths, test_index)
assert all(k in okapi_res for k in (1, 2, 3))
assert not any(k in okapi_res for k in (4, 5))
assert okapi_res[1] > okapi_res[3] > okapi_res[2]

# %% [markdown]
# ## 1.4. Setting up a server
#
# **Extra task \* (no penaly if skipped)** Organize the resulting search engine as a web-service that gets a query from get-parameters and returns urls with scores as a `json` dictionary. Check its work in a browser of with curl, should look smth like this:
#
# `> curl localhost:8080/?q=some_query_text
# { "url1" : 0.9, "url2": 0.8 }`
#
# You can use one of the following tools for this task:
# - https://www.acmesystems.it/python_http,
# - [http.server.ThreadingHTTPServer (3.7+)](https://docs.python.org/3/library/http.server.html#http.server.SimpleHTTPRequestHandler)
# - [Flask](https://pypi.org/project/Flask/)

# %%
#TODO write a web-service that answers queries using inverted index
from flask import Flask, request
app = Flask(__name__)

with open('inverted_index.p', 'rb') as fp:
    index = pickle.load(fp)
with open('doc_lengths.p', 'rb') as fp:
    doc_lengths = pickle.load(fp)
with open('doc_urls.p', 'rb') as fp:
    doc_urls = pickle.load(fp)

@app.route("/")
def hello():
    return "I am search engine. If you want okapi scoring got to /okapi, if you want boolean retrieval - got to /bool"

@app.route("/bool", methods=["GET"])
def boolean():
    query = request.args.get("q")
    prep_query = QueryProcessing.prepare_query(query)
    
    try:
        bool_res = QueryProcessing.boolean_retrieval(prep_query, index)
    except KeyError:
        return {"msg":"Could not find word in dict"}
    
    result = dict([(doc_id, doc_url) for doc_id, doc_url in doc_urls.items() if doc_id in bool_res])
    
    return result

@app.route("/okapi", methods=["GET"])
def okapi():
    query = request.args.get("q")
    prep_query = QueryProcessing.prepare_query(query)
    
    okapi_res = QueryProcessing.okapi_scoring(prep_query, doc_lengths, index)
    
    result = dict([(doc_url, okapi_res[doc_id]) for doc_id, doc_url in doc_urls.items() if doc_id in okapi_res])
    return result



app.run(host='0.0.0.0',port=8080)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:8080/ (Press CTRL+C to quit)
# 127.0.0.1 - - [08/Feb/2021 11:24:34] "GET /okapi?q=%22reuters%22 HTTP/1.1" 200 -

# %% [markdown]
# # 2. [55] Sorri not veri gud in inglish
#
# Have you ever googled someone's name without knowing exactly how it should be written? Were you ever reluctant to look up the correct spelling of a query you typed? Or just unable to type properly because of being in a rush? Modern search engines usually do a pretty good job in deciphering defective user input. In order to be able to do that, a good spell-checking mechanism should be incorporated into a search procedure. Today we will take one step further towards building a good search engine and work on tolerant retrieval with respect to user queries. We will consider two cases:
#
# 1. User knows that he doesn't know the correct spelling OR he wants to get the results that follow some known pattern, so he uses so called wildcards - queries like `retr*val`;
# 2. User doesn't know the correct spelling OR he doesn't care OR he's in a rush OR he expects his mistakes will be corrected OR your option, so he makes mistakes and we need to handle them using:
#
#     2.1. Simple spellchecker by Peter Norvig;
#
#     2.2. Phonetic correction by means of Soundex algorithm;
#
#     2.3. Trigrams with Jaccard coefficient.

# %% [markdown]
# ## 2.1. [20] Handling wildcards
#
# We will handle wildcard queries using k-grams. K-grams is a list of consecutive k chars in a string - i.e., for the word *'star'*, it will be '*\$st*', '*sta*', '*tar*', and '*ar$*', if we take k=3. Take a look at [book](https://nlp.stanford.edu/IR-book/pdf/irbookonlinereading.pdf) *chapter 3.2.2* to understand how k-grams can help efficiently match a wildcard against dictionary words. Here we will only consider wildcards with star symbols (may be multiple).
#
# Notice that for building k-grams index, **we will need a vocabulary of original word forms** to compare words in user input to the vocabulary of "correct" words (think why inverted index which we built for stemmed words doesn't work here).
#
# You need to implement the following:
#
# - `build_inverted_index_orig_forms` - creates inverted index of original world forms from `facts` list, which is already given to you.
#     Output format: `term:[collection_frequency, (doc_id_1, doc_freq_1), (doc_id_2, doc_freq_2), ...]`
#
#
# - `build_k_gram_index` - creates k-gram index which maps every k-gram encountered in facts collection to a list of words containing this k-gram. Use the abovementioned inverted index of original words to construct this index.
#     Output format: `'k_gram': ['word1_with_k_gram', 'word2_with_k_gram', ...]`
#
#
# - `generate_wildcard_options` - produce a list of vocabulary words matching given wildcard by intersecting postings of k-grams present in the wildcard (refer to *ch 3.2.2*).
#
# - `search_wildcard` - return list of facts that contain the words matching a wildcard query.
#
#
# We will use the dataset with curious facts for testing.
#
# ### 2.1.1. Downloading the dataset

# %%
import urllib.request
data_url = "https://raw.githubusercontent.com/hsu-ai-course/hsu.ai/master/code/datasets/nlp/facts.txt"
local_filename, headers = urllib.request.urlretrieve(data_url)

facts = []
with open(local_filename) as fp:
    for cnt, line in enumerate(fp):
        facts.append(line.strip('\n'))
        
print(*facts[-5:], sep='\n')
# Out:
# 151. Women have twice as many pain receptors on their body than men. But a much higher pain tolerance.
# 152. There are more stars in space than there are grains of sand on every beach in the world.
# 153. For every human on Earth there are 1.6 million ants.
# 154. The total weight of all those ants, however, is about the same as all the humans.
# 155. On Jupiter and Saturn it rains diamonds.

# %% [markdown]
# ### 2.1.2. [20] Implementation of search

# %%
import re


def build_inverted_index_orig_forms(documents):
    #TODO build an inverted index of original word forms 
    # (without stemming, just word tokenized and lowercased)
    
    def tokenize(text):
        #TODO word tokenize text using nltk lib
        return nltk.word_tokenize(text)
    
    inverted_index = {}
    
    for doc_id, docs in enumerate(documents):
        tokenized = tokenize(docs.lower())
        
        # Adding word to index
        for term in tokenized:
            if term in inverted_index:
                term_freq, docs_list = inverted_index[term][0], inverted_index[term][1:]
                docs_dict = dict(docs_list)

                term_freq += 1
                if doc_id in docs_dict:
                    docs_dict[doc_id] += 1
                else:
                    docs_dict[doc_id] = 1

                new_list = [term_freq]
                new_list.extend(list(docs_dict.items()))
                inverted_index[term] = new_list
            else:
                docs_dict = {doc_id: 1}
                new_list = [1]
                new_list.extend(list(docs_dict.items()))
                inverted_index[term] = new_list
    return inverted_index


def build_k_gram_index(inverted_index, k):
    #TODO build index of k-grams for dictionary words. 
    # Padd with '$' ($word$) before splitting to k-grams    

    k_gram_index = {}
    for word in inverted_index:
        new_word = "$" + word + "$"
        gram_list = [new_word[i:i + k] for i in range(0, len(new_word))]
        # truncating last not k-words
        if len(new_word) % k != 0:
            gram_list = gram_list[:-(len(new_word) % k)]

        for gram in gram_list:
            if gram in k_gram_index:
                k_gram_index[gram].append(word)
            else:
                k_gram_index[gram] = [word]
    
    return k_gram_index


def generate_wildcard_options(wildcard, k_gram_index, inverted_index):
    #TODO for a given wildcard return all words matching it using k-grams
    # refer to book chapter 3.2.2
    # don't forget to pad wildcard with '$', when appropriate
    new_wildcard = "$" + wildcard + "$"
    k = len(list(k_gram_index.keys())[0])
    gram_list = [new_wildcard[i:i + k] for i in range(0, len(new_wildcard))]
    # truncating last not k-words
    if len(new_wildcard) % k != 0:
        gram_list = gram_list[:-(len(new_wildcard) % k)]

    gram_list_trunc = list(filter(lambda x: x != "$" and "*" not in x, gram_list))

    option_set = set()
    for word in gram_list_trunc:
        if word in k_gram_index:
            if not option_set:
                option_set.update(k_gram_index[word])
            else:
                option_set.intersection_update(k_gram_index[word])
    return list(option_set)


def search_wildcard(wildcard, k_gram_index, index, docs):
    #TODO retrive list of documnets (facts) that contain words matching wildcard
    def union_retrieval():
        #TODO retrieve a set of documents containing all query terms
        set_docs = None
        for word in query:
            if set_docs:
                set_docs = set_docs.union(set([x[0] for x in index[word][1:]]))
            else:
                set_docs = set([x[0] for x in index[word][1:]])
        
        return set_docs

    query = generate_wildcard_options(wildcard, k_gram_index, index)
    doc_ids = union_retrieval()
    if doc_ids:
        return [doc for doc_id, doc in enumerate(docs) if doc_id in doc_ids]
    return []

# %% [markdown]
# ### 2.1.3. Tests

# %%
index_orig_forms = build_inverted_index_orig_forms(facts)
k_gram_index = build_k_gram_index(index_orig_forms, 3)

wildcard = "re*ed"

wildcard_options = generate_wildcard_options(wildcard, k_gram_index, index_orig_forms)
print(wildcard_options)
assert(len(wildcard_options) >= 3)

wildcard_results = search_wildcard(wildcard, k_gram_index, index_orig_forms, facts)
# some pretty printing
for r in wildcard_results:
    # highlight terms for visual evaluation
    for term in wildcard_options:
        r = re.sub(r'(' + term + ')', r'\033[1m\033[91m\1\033[0m', r, flags=re.I)
    print(r)

assert(len(wildcard_results) >=3)

assert "13. James Buchanan, the 15th U.S. president continuously bought slaves with his own money in order to free them." in search_wildcard("pres*dent", k_gram_index, index_orig_forms, facts)
assert "40. 9 out of 10 Americans are deficient in Potassium." in search_wildcard("p*tas*um", k_gram_index, index_orig_forms, facts)
assert "61. A man from Britain changed his name to Tim Pppppppppprice to make it harder for telemarketers to pronounce." in search_wildcard("*price", k_gram_index, index_orig_forms, facts)
# Out:
# ['received', 'recorded', 'reduced']
# 4. The largest recorded snowflake was in Keogh, MT during year 1887, and was 15 inches wide.
# 102. More than 50% of the people in the world have never made or received a telephone call.
# 134. A person can live without food for about a month, but only about a week without water. If the amount of water in your body is reduced by just 1%, you'll feel thirsty. If it's reduced by 10%, you'll die.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-7-c6fba6b2f266> in <module>
#      19
#      20 assert "13. James Buchanan, the 15th U.S. president continuously bought slaves with his own money in order to free them." in search_wildcard("pres*dent", k_gram_index, index_orig_forms, facts)
# ---> 21 assert "40. 9 out of 10 Americans are deficient in Potassium." in search_wildcard("p*tas*um", k_gram_index, index_orig_forms, facts)
#      22 assert "61. A man from Britain changed his name to Tim Pppppppppprice to make it harder for telemarketers to pronounce." in search_wildcard("*price", k_gram_index, index_orig_forms, facts)
#
# AssertionError:

# %% [markdown]
# ## 2.2. [35] Handling typos
#
# ### 2.2.1 Dataset
#
# Download github typo dataset from [here](https://github.com/mhagiwara/github-typo-corpus).
# Load it with this code:

# %%
# !pip install jsonlines

# %%
import jsonlines

dataset_file = "github-typo-corpus.v1.0.0.jsonl"

dataset = []
other_langs = set()

with jsonlines.open(dataset_file) as reader:
    for obj in reader:
        for edit in obj['edits']:
            if edit['src']['lang'] != 'eng':
                other_langs.add(edit['src']['lang'])
                continue

            if edit['is_typo']:
                src, tgt = edit['src']['text'], edit['tgt']['text']
                if src.lower() != tgt.lower():
                    dataset.append((edit['src']['text'], edit['tgt']['text']))
                
print(f"Dataset size = {len(dataset)}")
# Out:
# Dataset size = 245909

# %% [markdown]
# #### Explore sample typos
# Please, explore the dataset. You may see, that this is
# - mostly markdown
# - some common mistakes with do/does
# - some just refer to punctuation typos (which we do not consider)

# %%
for pair in dataset[1010:1020]:
    print(f"{pair[0]} => {pair[1]}")
# Out:
#         """Make am instance. =>         """Make an instance.
# * travis: test agains Node.js 11 => * travis: test against Node.js 11
# The parser receive a string and returns an array inside a user-provided  => The parser receives a string and returns an array inside a user-provided
# CSV data is send through the `write` function and the resulted data is obtained => CSV data is sent through the `write` function and the resulting data is obtained
# One useful function part of the Stream API is `pipe` to interact between  => One useful function of the Stream API is `pipe` to interact between
# source to a `stream.Writable` object destination. This example available as  => source to a `stream.Writable` object destination. This example is available as
# `node samples/pipe.js` read the file, parse its content and transform it. => `node samples/pipe.js` and reads the file, parses its content and transforms it.
# Most of the generator is imported from its parent project [CSV][csv] in a effort  => Most of the generator is imported from its parent project [CSV][csv] in an effort
# *   `quote`             Optionnal character surrounding a field, one character only, defaults to double quotes.    => *   `quote`             Optional character surrounding a field, one character only, defaults to double quotes.
# The parser receive a string and return an array inside a user-provided  => The parser receive a string and returns an array inside a user-provided

# %% [markdown]
# ### 2.2.2. [5] Build a dataset vocabulary
# We will need it for Norvig's spellchecker as well as for estimating overall correction quality. Consider only word-level. Be carefull, there is markdown (e.g. \`name\`. \[url\]\(http://url)) and comment symbols (\#, //, \*).

# %%
def sent_to_words(sent):
    # splits sentence to words, filtering out non-alphabetical terms
    words = nltk.word_tokenize(sent)    
    words_filtered = filter(lambda x: x.isalpha(), words)
    return words_filtered

# %%
vocabulary = Counter()
for pair in dataset:
    for word in sent_to_words(pair[1].lower()):
        vocabulary[word] += 1
len(vocabulary)
# Out:
# 63724

# %%
from itertools import islice
print(list(islice(vocabulary.items(), 10)))
# Out:
# [('function', 6193), ('de', 82), ('deutsch', 4), ('nocomments', 2), ('you', 42075), ('can', 26027), ('disable', 532), ('comments', 360), ('for', 44756), ('the', 207017)]

# %% [markdown]
# ### 2.2.3. [25] Implement context-independent spellcheker ##
#
# 0) Write code to compute editorial distance
#
# 1) [Norvig's corrector](https://norvig.com/spell-correct.html)
#
# 2) [Soundex](https://en.wikipedia.org/wiki/Soundex)
#
# 3) Trigrams with Jaccard coefficient.
#
# #### 2.2.3.0. [5] Editorial distance
#
# Frequently used distance measure between two character sequences. We will use this distance to sort Soundex search results.

# %%
def edit_dist(s1, s2) -> int:
    # TODO compute the Damerau-Levenshtein distance between two given strings (s1 and s2)
        d = {}
        lenstr1 = len(s1)
        lenstr2 = len(s2)
        for i in range(-1,lenstr1+1):
            d[(i,-1)] = i+1
        for j in range(-1,lenstr2+1):
            d[(-1,j)] = j+1

        for i in range(lenstr1):
            for j in range(lenstr2):
                if s1[i] == s2[j]:
                    cost = 0
                else:
                    cost = 1
                d[(i,j)] = min(
                               d[(i-1,j)] + 1, # deletion
                               d[(i,j-1)] + 1, # insertion
                               d[(i-1,j-1)] + cost, # substitution
                              )
                if i and j and s1[i]==s2[j-1] and s1[i-1] == s2[j]:
                    d[(i,j)] = min (d[(i,j)], d[i-2,j-2] + cost) # transposition

        return d[lenstr1-1,lenstr2-1]

# %%
# tests

assert edit_dist("korrectud", "corrected") == 2, "Edit distance is computed incorrectly"
assert edit_dist("soem", "some") == 1, "Edit distance is computed incorrectly"
assert edit_dist("one", "one") == 0, "Edit distance is computed incorrectly"

# %% [markdown]
# #### 2.2.3.1. [5] Norvig's spellchecker

# %%
# Thanks to Peter Norvig :)

def fix_typo_norvig(word) -> str:
    def P(word, N=sum(vocabulary.values())): 
        "Probability of `word`."
        return vocabulary[word] / N

    def candidates(word): 
        "Generate possible spelling corrections for word."
        return (known([word]) or known(edits1(word)) or known(edits2(word)) or [word])

    def known(words): 
        "The subset of `words` that appear in the dictionary of WORDS."
        return set(w for w in words if w in vocabulary)

    def edits1(word):
        "All edits that are one edit away from `word`."
        letters    = 'abcdefghijklmnopqrstuvwxyz'
        splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
        deletes    = [L + R[1:]               for L, R in splits if R]
        transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
        replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
        inserts    = [L + c + R               for L, R in splits for c in letters]
        return set(deletes + transposes + replaces + inserts)

    def edits2(word): 
        "All edits that are two edits away from `word`."
        return (e2 for e1 in edits1(word) for e2 in edits1(e1))
    
    return max(candidates(word), key=P)

# %%
# tests

assert fix_typo_norvig("korrectud") == "corrected", "Norvig's correcter doesn't work"
assert fix_typo_norvig("speling") == "spelling", "Norvig's correcter doesn't work"

# %% [markdown]
# #### 2.2.3.2. [10] Soundex
#
# For cases when the exact spelling is unknown, phonetic algorithms such as Soundex can be very helpful - they allow user to type a word the way he thinks it should sound, and then suggest the corrrect version. Go through *chapter 3.4* to understand how Soundex algorithm works.

# %%
def produce_soundex_code(word):
    #TODO implement Soundex algorithm, version from book chapter 3.4
    # input word is already lowercased
    # return Soundex 4-character code, like 'k450'
    letter_dict = {
        'a': '0', 'e': '0', 'i': '0', 'o': '0', 'u': '0', 'h': '0', 'w': '0', 'y': '0',
        'b': '1', 'f': '1', 'p': '1', 'v': '1',
        'c': '2', 'g': '2', 'j': '2', 'k': '2', 'q': '2', 's': '2', 'x': '2', 'z': '2',
        'd': '3', 't': '3',
        'l': '4',
        'm': '5', 'n': '5',
        'r': '6'
    }
    # Changing letters to digits
    if all([True if letter in letter_dict else False for letter in word]):
        #print([True for letter in word if (letter in letter_dict) else False])
        soundex_list = [word[0]]
        for letter in word[1:]:
            soundex_list.append(letter_dict[letter])

        # Removing pairs of consecutive digits
        for i in range(1, len(soundex_list) - 1):
            if soundex_list[i] == soundex_list[i + 1]:
                soundex_list[i] = '-'

        # Deleting all zeros and adding trailing zeros
        soundex_word = "".join(list(filter(lambda x: x != '0' and x != '-', soundex_list))) + "0000"

        return soundex_word[:4]
    return None


def build_soundex_index(dictionary):
    #TODO build soundex index for dictionary words.
    # dictionary is a vocabulary of original words
    # output format: 'code1': ['word1_with_code1', 'word2_with_code1', ...]    
    soundex_index = {}
    for word in dictionary:
        code = produce_soundex_code(word)
        if code:
            if code in soundex_index:
                soundex_index[code].append(word)
            else:
                soundex_index[code] = [word]

    return soundex_index


def fix_typo_soundex(word, soundex_index) -> list:
    #TODO return words from vocabulary that match with result by soundex fingerprint
    # ordered results by editorial distance
    
    sound_word = produce_soundex_code(word)
    matched_words = soundex_index.get(sound_word, [])
    
    return matched_words or [word]

# %%
# tests

soundex_index = build_soundex_index(vocabulary)

code1 = produce_soundex_code("britney")
code2 = produce_soundex_code("breatany")
print(code1, code2)
assert code1 == code2

print(fix_typo_soundex("enouhg", soundex_index))
assert "enough" in fix_typo_soundex("enouhg", soundex_index), "Assert soundex failed"
# Out:
# b635 b635
# ['enjoy', 'enough', 'emacs', 'emoji', 'emc', 'emas', 'enqueue', 'euank', 'ensue', 'eng', 'emq', 'enmasse', 'emac', 'ens', 'enc', 'emojii', 'enki', 'enso', 'enzo', 'enwiki', 'emmc', 'emesh', 'emg', 'emgo']

# %% [markdown]
# #### 2.2.3.3. [5] Trigrams with Jaccard coefficient

# %%
def fix_typo_kgram(word, k_gram_index) -> list:
    #TODO return best matches with respect to Jaccard index   
    k = max(len(x) for x in k_gram_index)

    def make_grams(word):
        return [
            word[i:i+ki]
            for ki in range(2, k + 1)
            for i in range(len(word) - ki + 1)
        ]

    def calc_jaccard(word):
        curr_grams = make_grams(word)
        inter = grams.intersection(curr_grams)
        union = grams.union(curr_grams)
        return len(inter) / len(union)

    grams = set(make_grams(word))
    candidates = set(word for gram in grams for word in k_gram_index.get(gram, [])) 
    return sorted(candidates, key=calc_jaccard, reverse=True)[:10] or [word]

# %%
# tests

k_gram_index_github = build_k_gram_index(vocabulary, 3)
print(fix_typo_kgram("enouh", k_gram_index_github)[:20])
assert "enough" in fix_typo_kgram("enouh", k_gram_index_github), "Assert k-gram failed"
# Out:
# ['enough', 'eno', 'enought', 'nous', 'renounce', 'noun', 'deno', 'exogenous', 'endogenous', 'menoh']

# %% [markdown]
# ## 2.2.4. [5] Estimate quality

# %%
norvig, soundex, kgram = 0, 0, 0
limit = 10000
counter = limit
for i, (src, target) in enumerate(dataset):
    if i == limit:
        break
    words = sent_to_words(src.lower())
    # word suspected for typos
    sn, ss, sk = src.lower(), src.lower(), src.lower()
    for word in words:
        if word not in vocabulary and word.isalpha():
            # top-1 accuracy
            wn, ws, wk = fix_typo_norvig(word), \
                         fix_typo_soundex(word, soundex_index)[0], \
                         fix_typo_kgram(word, k_gram_index_github)[0]
            sn = sn.replace(word, wn)
            ss = ss.replace(word, ws)
            sk = sk.replace(word, wk)
    norvig += int(sn == target.lower())
    soundex += int(ss == target.lower())
    kgram += int(sk == target.lower())

print(f"Norvig accuracy ({norvig}) = {norvig / limit}")
print(f"Soundex accuracy ({soundex}) = {soundex / limit}")
print(f"k-gram accuracy ({kgram}) = {kgram / limit}")
# Out:
# Norvig accuracy (2429) = 0.2429
# Soundex accuracy (648) = 0.0648
# k-gram accuracy (1316) = 0.1316
