# %% [markdown]
# # Crawler
# ## 1. Download and persist #
# Please complete a code for `load()`, `download()` and `persist()` methods of `Document` class. What they do:
# - for a given URL `download()` method downloads binary data and stores in `self.content`. It returns `True` for success, else `False`.
# - `persist()` method saves `self.content` somewhere in file system. We do it to avoid multiple downloads (for caching in other words).
# - `load()` method loads data from hard drive. Returns `True` for success.
#
# Tests checks that your code somehow works.

# %%
import requests
from urllib.parse import quote, urlparse
import requests
import os

class Document:
    
    def __init__(self, url):
        self.url = url
        
        parsed_url = urlparse(self.url)
        self.file_path = "".join(["data//", parsed_url.netloc, ".", *parsed_url.path.split("/")])
        
    def get(self):
        if not self.load():
            if not self.download():
                raise FileNotFoundError(self.url)
            else:
                self.persist()
    
    def download(self):
        #TODO download self.url content, store it in self.content and return True in case of success
        response = requests.get(self.url)
        if response.status_code == 200:
            self.content = response.content.decode(response.encoding)
            return True
        return False
    
    def persist(self):
        #TODO write document content to hard drive
        os.makedirs(os.path.dirname(self.file_path), exist_ok=True)
        with open(self.file_path, "w") as f:
            f.write(self.content)
            
    def load(self):
        #TODO load content from hard drive, store it in self.content and return True in case of success
        if os.path.isfile(self.file_path):
            with open(self.file_path, "r") as f:
                self.content = f.read()
                return True
        return False

# %% [markdown]
# ### 1.1. Tests ###

# %%
doc = Document('http://sprotasov.ru/data/iu.txt')

doc.get()
assert doc.content, "Document download failed"
assert "Code snippets, demos and labs for the course" in str(doc.content), "Document content error"

doc.get()
assert doc.load(), "Load should return true for saved document"
assert "Code snippets, demos and labs for the course" in str(doc.content), "Document load from disk error"

# %% [markdown]
# ## 2. Parse HTML ##
# `BeautifulSoap` library is a de facto standard to parse XML and HTML documents in python. Use it to complete `parse()` method that extracts document contents. You should initialize:
# - `self.anchors` list of tuples `('text', 'url')` met in a document. Be aware, there exist relative links (e.g. `../content/pic.jpg`). Use `urllib.parse.urljoin()` to fix this issue.
# - `self.images` list of images met in a document. Again, links can be relative to current page.
# - `self.text` should keep plain text of the document without scripts, tags, comments and so on. You can refer to [this stackoverflow answer](https://stackoverflow.com/a/1983219) for details.

# %%
from bs4 import BeautifulSoup, SoupStrainer
from bs4.element import Comment
import urllib.parse


class HtmlDocument(Document):
    
    def parse(self):
        #TODO exctact plain text, images and links from the document
        def parse_text():
            soup = BeautifulSoup(self.content)
            [s.extract() for s in soup(['style', 'script', '[document]', 'head', 'title'])]
            return soup.getText()
        
        def parse_links():
            ## Parse only 'a' attribute and get links from their
            soup = BeautifulSoup(self.content, parse_only=SoupStrainer('a'))
            return [(link.contents, urllib.parse.urljoin(self.url, link['href'])) for link in soup if link.has_attr('href')]
            
        def parse_imgs():
            soup = BeautifulSoup(self.content, parse_only=SoupStrainer('img'))
            return [urllib.parse.urljoin(self.url, link['src']) for link in soup if link.has_attr('src')]
        

        self.anchors = parse_links()
        self.images = parse_imgs()
        self.text = parse_text()

# %% [markdown]
# ### 2.1. Tests ###

# %%
doc = HtmlDocument("http://sprotasov.ru")
doc.get()
doc.parse()

assert "тестирующий сервер codetest" in doc.text, "Error parsing text"
assert "http://sprotasov.ru/images/phone.png" in doc.images, "Error parsing images"
assert any(p[1] == "http://university.innopolis.ru/" for p in doc.anchors), "Error parsing links"

# %% [markdown]
# ## 3. Document analysis ##
# Complete the code for `HtmlDocumentTextData` class. Implement word and sentence splitting (use any method you can propose). Your `get_word_stats()` method should return `Counter` object. Don't forget to lowercase your words.

# %%
from collections import Counter
import nltk, string

nltk.download('punkt')

class HtmlDocumentTextData:
    
    def __init__(self, url):
        self.doc = HtmlDocument(url)
        self.doc.get()
        self.doc.parse()
    
    def get_sentences(self):
        #TODO*: implement sentence parser
        words = nltk.word_tokenize(self.doc.text)
        cleaned_words = [w.lower() for w in words if w.isalpha()]
        return cleaned_words
    
    def get_word_stats(self):
        #TODO return Counter object of the document, containing mapping {`word` -> count_in_doc}
        cleaned_words = self.get_sentences()
        return Counter(cleaned_words)
# Out:
# [nltk_data] Downloading package punkt to /Users/osmiyg/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### 3.1. Tests ###

# %%
doc = HtmlDocumentTextData("https://innopolis.university/")

print(doc.get_word_stats().most_common(10))
assert [x for x in doc.get_word_stats().most_common(10) if x[0] == 'иннополис'], 'иннополис sould be among most common'
# Out:
# [('и', 46), ('в', 28), ('иннополис', 21), ('по', 14), ('на', 12), ('университета', 10), ('университет', 10), ('лаборатория', 10), ('с', 8), ('об', 7)]

# %% [markdown]
# ## 4. Crawling ##
#
# Method `crawl_generator()` is given starting url (`source`) and max depth of search. It should return a **generator** of `HtmlDocumentTextData` objects (return a document as soon as it is downloaded and parsed). You can benefit from `yield obj_name` python construction. Use `HtmlDocumentTextData.anchors` field to go deeper.

# %%
class Crawler:
    
    def crawl_generator(self, source, depth=1):
        #TODO return real crawling results. Don't forget to process failures
        queue = []
        checked = set()
        tmp_anchor_list = []
        
        # Put initial links
        try:
            src = HtmlDocumentTextData(source)
            checked.add(source)
            yield src
            for anchor in src.doc.anchors:
                queue.append(anchor)
        except Exception as e:
            print(e)
            
        # Going until depth is satisified
        for i in range(depth):
            while (queue):
                try:
                    link = queue.pop(0)[1]
                    # We procceed if the link was not crawled before
                    if link not in checked:
                        checked.add(link)
                        src = HtmlDocumentTextData(link)
                        yield src
                        for anchor in src.doc.anchors:
                            tmp_anchor_list.append(anchor)
                        
                except Exception as e:
                    print(e)
            for anchor in tmp_anchor_list:
                    queue.append(anchor)
            tmp_anchor_list = []

# %% [markdown]
# ### 4.1. Tests ###

# %%
crawler = Crawler()
counter = Counter()

for c in crawler.crawl_generator("https://innopolis.university/en/", 2):
    print(c.doc.url)
    if c.doc.url[-4:] in ('.pdf', '.mp3', '.avi', '.mp4', '.txt'):
        print("Skipping", c.doc.url)
        continue
    counter.update(c.get_word_stats())
    print(len(counter), "distinct word(s) so far")
    
print("Done")

print(counter.most_common(20))
assert [x for x in counter.most_common(20) if x[0] == 'innopolis'], 'innopolis sould be among most common'
# Out:
# https://innopolis.university/en/
# 280 distinct word(s) so far
# http://old.innopolis.university/en/
# 300 distinct word(s) so far
# https://media.innopolis.university/en/
# 422 distinct word(s) so far
# https://www.facebook.com/InnopolisU
# 573 distinct word(s) so far
# https://vk.com/innopolisu
# 807 distinct word(s) so far
# https://www.youtube.com/user/InnopolisU
# 817 distinct word(s) so far
# https://twitter.com/InnopolisU
# https://www.instagram.com/innopolisu/
# 817 distinct word(s) so far
# https://habr.com/ru/users/t-fazullin/posts/
# 1501 distinct word(s) so far
# https://apply.innopolis.university/en/
# 2185 distinct word(s) so far
# https://corporate.innopolis.university/
# 2436 distinct word(s) so far
# https://media.innopolis.university/
# 2676 distinct word(s) so far
# https://innopolis.university/lk/
# 2805 distinct word(s) so far
# https://innopolis.university/en/about/
# 2900 distinct word(s) so far
# https://innopolis.university/en/board/
# 2963 distinct word(s) so far
# https://innopolis.university/en/team/
# 2964 distinct word(s) so far
# https://innopolis.university/en/team-structure/
# 2967 distinct word(s) so far
# https://innopolis.university/en/education-academics/
# 2970 distinct word(s) so far
# https://innopolis.university/en/techcenters/
# 2972 distinct word(s) so far
# https://innopolis.university/en/faculty/
# 3862 distinct word(s) so far
# https://career.innopolis.university/en/job/
# 3932 distinct word(s) so far
# https://career.innopolis.university/en/
# 4200 distinct word(s) so far
# https://innopolis.university/en/campus/
# 4531 distinct word(s) so far
# https://innopolis.university/en/contacts/
# 4533 distinct word(s) so far
# https://apply.innopolis.university/en/postgraduate-study/
# 4592 distinct word(s) so far
# https://apply.innopolis.university/en/bachelor/
# 4640 distinct word(s) so far
# https://apply.innopolis.university/en/master/
# 4654 distinct word(s) so far
# https://innopolis.university/en/datascience
# https://innopolis.university/en/razrabotka-bezopasnyh-sistem-i-setej/
# https://innopolis.university/en/development2/
# https://innopolis.university/en/robotics/
# https://apply.innopolis.university/en/grant/
# 4655 distinct word(s) so far
# https://apply.innopolis.university/en/stud-life/
# 4715 distinct word(s) so far
# https://innopolis.university/en/international-relations-office/
# 5293 distinct word(s) so far
# https://innopolis.university/en/incomingstudents/
# 5364 distinct word(s) so far
# https://innopolis.university/en/outgoingstudents/
# 5395 distinct word(s) so far
# https://innopolis.university/en/research/
# 5418 distinct word(s) so far
# https://innopolis.university/en/Labofoperatingsystemsprogramminglanguagesandcompilers/
# 5441 distinct word(s) so far
# https://innopolis.university/en/Labofsoftwareandserviceengineering/
# 5528 distinct word(s) so far
# https://innopolis.university/en/labofindustrializingsoftwareproduction /
# 5555 distinct word(s) so far
# https://innopolis.university/en/Labofdataanalysisandbioinformatics/
# 5597 distinct word(s) so far
# https://innopolis.university/en/Labofartificialintelligenceingamedevelopment2/
# 5644 distinct word(s) so far
# https://innopolis.university/en/labofdataanalysisandmachinelearningintheoilandgasindustry/
# 5689 distinct word(s) so far
# https://innopolis.university/en/Labofmachinelearningandknowledgerepresentation/
# 5781 distinct word(s) so far
# https://innopolis.university/en/Labofcyberphysicalsystems/
# 5811 distinct word(s) so far
# https://innopolis.university/en/networksandblockchainlab/
# 5890 distinct word(s) so far
# https://innopolis.university/en/laboratoriya-intellektualnyh-robototekhnicheskih-sistem/
# 5966 distinct word(s) so far
# https://innopolis.university/en/activity/
# 6000 distinct word(s) so far
# https://innopolis.university/en/podderzhka-innovacionnoj-deyatelnosti/
# 6026 distinct word(s) so far
# https://innopolis.university/en/internationalpartners/
# 6039 distinct word(s) so far
# https://innopolis.university/en/organizatsiya-i-provedenie-meropriyatiy/
# 6116 distinct word(s) so far
# https://innopolis.university/en/search/
# 6116 distinct word(s) so far
# https://innopolis.university/
# 6130 distinct word(s) so far
# https://innopolis.university/profile/
# https://innopolis.university/search/
# 6133 distinct word(s) so far
# https://university.innopolis.ru/en/about/
# 6133 distinct word(s) so far
# http://www.campuslife.innopolis.ru
# 6206 distinct word(s) so far
# https://media.innopolis.university/en/news/webinar-interstudents-eng/
# 6220 distinct word(s) so far
# https://media.innopolis.university/en/news/devops-summer-school/
# 6250 distinct word(s) so far
# https://media.innopolis.university/en/news/webinar-for-international-candidates-/
# 6253 distinct word(s) so far
# https://media.innopolis.university/en/news/registration-innopolis-open-2020/
# 6262 distinct word(s) so far
# https://media.innopolis.university/en/news/cyber-resilience-petrenko/
# 6297 distinct word(s) so far
# https://media.innopolis.university/en/news/innopolis-university-extends-international-application-deadline-/
# 6300 distinct word(s) so far
# https://media.innopolis.university/en/news/self-driven-school/
# 6307 distinct word(s) so far
# https://university.innopolis.ru/en/news/
# https://apply.innopolis.ru/en/index.php
# 6349 distinct word(s) so far
# https://university.innopolis.ru/en/cooperation/
# https://media.innopolis.university/en/news/
# 6349 distinct word(s) so far
# https://media.innopolis.university/en/events/
# 6350 distinct word(s) so far
# http://www.minsvyaz.ru/en/
# 6396 distinct word(s) so far
# HTTPConnectionPool(host='xn--80abucjiibhv9a.xn--p1ai', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7faea0da6f40>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# decode() argument 'encoding' must be str, not None
# http://old.innopolis.university/
# 6396 distinct word(s) so far
# No connection adapters were found for 'mailto:devs@innopolis.university'
# https://apply.innopolis.university/
# 6622 distinct word(s) so far
# http://www.campuslife.innopolis.ru/main
# 6622 distinct word(s) so far
# http://media.innopolis.university/
# 6622 distinct word(s) so far
# https://media.innopolis.university
# 6622 distinct word(s) so far
# https://media.innopolis.university/en/?TAGS=*
# 6622 distinct word(s) so far
# https://media.innopolis.university/en/?TAGS=Industry
# 6622 distinct word(s) so far
# https://media.innopolis.university/en/?TAGS=Research
# 6622 distinct word(s) so far
# https://media.innopolis.university/en/?TAGS=Education
# 6622 distinct word(s) so far
# https://media.innopolis.university/en/?TAGS=Students life
# 6622 distinct word(s) so far
# https://media.innopolis.university/en/?TAGS=Global
# 6622 distinct word(s) so far
# https://media.innopolis.university/en/?TAGS=Robotics
# 6622 distinct word(s) so far
# https://media.innopolis.university/en/?TAGS=Blockchain
# 6622 distinct word(s) so far
# https://media.innopolis.university/en/?TAGS=Cybersecurity
# 6622 distinct word(s) so far
# https://media.innopolis.university/en/news/webinar-for-international-candidates/
# 6624 distinct word(s) so far
# https://media.innopolis.university/en/news/the-first-release-for-testers-in-innopolis-university/
# 6662 distinct word(s) so far
# https://media.innopolis.university/en/?PAGEN_2=2
# 6662 distinct word(s) so far
# https://media.innopolis.university/en/?PAGEN_2=3
# 6662 distinct word(s) so far
# https://media.innopolis.university/en/?PAGEN_2=38
# 6662 distinct word(s) so far
# https://media.innopolis.university/en/?PAGEN_2=39
# 6662 distinct word(s) so far
# https://spec.innopolis.university/
# 6703 distinct word(s) so far
# https://www.youtube.com/channel/UCZNo9zTHZNZOW4fSFcCKh_A
# 6703 distinct word(s) so far
# decode() argument 'encoding' must be str, not None
# https://www.facebook.com/
# 6734 distinct word(s) so far
# https://www.facebook.com/recover/initiate?lwv=110&ars=royal_blue_bar
# 6740 distinct word(s) so far
# https://www.facebook.com/InnopolisU/?ref=page_internal
# 6740 distinct word(s) so far
# https://www.facebook.com/InnopolisU/about/?ref=page_internal
# 6777 distinct word(s) so far
# https://www.facebook.com/InnopolisU/photos/?ref=page_internal
# 6784 distinct word(s) so far
# https://www.facebook.com/InnopolisU/reviews/?ref=page_internal
# 6804 distinct word(s) so far
# https://www.facebook.com/InnopolisU/videos/?ref=page_internal
# 6806 distinct word(s) so far
# https://www.facebook.com/InnopolisU/events/?ref=page_internal
# 6807 distinct word(s) so far
# https://www.facebook.com/InnopolisU/posts/?ref=page_internal
# 7551 distinct word(s) so far
# https://www.facebook.com/InnopolisU/community/?ref=page_internal
# 7555 distinct word(s) so far
# https://www.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2FInnopolisU%2F&privacy_mutation_token=eyJ0eXBlIjowLCJjcmVhdGlvbl90aW1lIjoxNjExNDA0MDc3LCJjYWxsc2l0ZV9pZCI6Mzc4Mzc1MTU5OTY2NjIxfQ%3D%3D
# 7558 distinct word(s) so far
# https://www.facebook.com/reg/?rs=2&privacy_mutation_token=eyJ0eXBlIjowLCJjcmVhdGlvbl90aW1lIjoxNjExNDA0MDc3LCJjYWxsc2l0ZV9pZCI6Mzc4Mzc1MTU5OTY2NjIxfQ%3D%3D
# 7603 distinct word(s) so far
# https://www.facebook.com/reg/?rs=1&privacy_mutation_token=eyJ0eXBlIjowLCJjcmVhdGlvbl90aW1lIjoxNjExNDA0MDc3LCJjYWxsc2l0ZV9pZCI6NjQ4NzMxOTgyNDk1ODQyfQ%3D%3D
# 7603 distinct word(s) so far
# https://www.facebook.com/InnopolisU/reviews/
# 7603 distinct word(s) so far
# https://www.facebook.com/InnopolisU/community/
# 7603 distinct word(s) so far
# https://www.facebook.com/InnopolisU/about/
# 7603 distinct word(s) so far
# http://l.facebook.com/l.php?u=http%3A%2F%2Fshare.here.com%2Fr%2Fmylocation%2Fe-...%3D%3D%3Flink%3Daddresses%26fb_locale%3Dru_RU%26ref%3Dfacebook&h=AT1ij4kb1eO9_TyUAZTTGlYtwucbAfUCfkxRxLvefQLoYlCtKgZrXCbMSDnkUp7F4QZn6HV08a5jvxYmcwEyo08JGHLDIscfOSJMddKIAsDpcgJMvotR9RMIDK05IBmnDz5aoU2DFSifsoHN
# 7603 distinct word(s) so far
# https://l.facebook.com/l.php?u=https%3A%2F%2Funiversity.innopolis.ru%2F&h=AT3WruLUcZkilX1fFXiZi4QL75J3wlADHL_braTGmGMB2yA8Po-WXiYluJZZIsiB5-0-MFudGEB7Q20-1aX1FTtb4b544yLsgEg3vj6gxXMU6Tm3RIX2ZdnVf24qda5Az6gnWL_2VqiY1-eX
# 7603 distinct word(s) so far
# https://www.facebook.com/search/?bqf=str%2F%25D0%2592%25D1%2583%25D0%25B7%25D1%258B%2Fkeywords_pages&ref=page_about_category&f=AbqkI9sFKel8xWcTCmDuJJjWg105qHwrlRvHPxd05W_yVLYll0GFl2abteadAYRz03Dee2Miv5Oc3XOY3JCFM3RPqNgArnWXuhd7fpR4MjZ2PZ9i48tiWwIbLxOwY0VCu0M
# https://www.facebook.com/search/?bqf=str%2F%25D0%25A8%25D0%25BA%25D0%25BE%25D0%25BB%25D0%25B0%2Fkeywords_pages&ref=page_about_category&f=AbqSKZzBBy--zaC4oXJW-2awubIAAYgReqC1Rx5TCPuwRPOISHP_SUOqZ25zAbSFrhUX_EhtjMOfuASjkiprL0NztkZqEc4qKn2EZr0Jk0TQev0fxWRyy-zB9Jo_zZW3MGTrZSkXQyGneOvLF4ybISOZ
# https://www.facebook.com/InnopolisU/likes?ref=page_internal
# 7603 distinct word(s) so far
# https://www.facebook.com/InnopolisU/likes
# 7603 distinct word(s) so far
# https://www.facebook.com/sezinnopolis/?ref=py_c
# 7812 distinct word(s) so far
# https://www.facebook.com/MAIglobal/?ref=py_c
# 7916 distinct word(s) so far
# https://www.facebook.com/Skoltech/?ref=py_c
# 8110 distinct word(s) so far
# https://www.facebook.com/intprograms.SPbSPU/?ref=py_c
# 8174 distinct word(s) so far
# https://www.facebook.com/indemedia/?ref=py_c
# 8282 distinct word(s) so far
# https://www.facebook.com/universityofgroningen/?ref=py_c
# 8395 distinct word(s) so far
# https://www.facebook.com/dobriytrener/?ref=py_c
# 8423 distinct word(s) so far
# https://www.facebook.com/InnopolisStudents/?ref=py_c
# 8465 distinct word(s) so far
# https://www.facebook.com/МГУ-Московский-Государственный-Университет-им-МВЛомоносова-259593544088513/?ref=py_c
# 8516 distinct word(s) so far
# https://www.facebook.com/internationalhse/?ref=py_c
# 8671 distinct word(s) so far
# https://www.facebook.com/mgimo.university/?ref=py_c
# 8791 distinct word(s) so far
# https://www.facebook.com/zuhairabbas1214/?ref=py_c
# 8830 distinct word(s) so far
# https://www.facebook.com/SBSynergy/?ref=py_c
# 8909 distinct word(s) so far
# https://www.facebook.com/trikset/?ref=py_c
# 9011 distinct word(s) so far
# https://www.facebook.com/SokaUniversityofAmerica/?ref=py_c
# 9148 distinct word(s) so far
# https://www.facebook.com/pulsarventurecapital/?ref=py_c
# 9321 distinct word(s) so far
# https://www.facebook.com/highschoolofamerica/?ref=py_c
# 9370 distinct word(s) so far
# https://www.facebook.com/skolkovo/?ref=py_c
# 9426 distinct word(s) so far
# https://www.facebook.com/shtabkazan/?ref=py_c
# 9458 distinct word(s) so far
# https://www.facebook.com/Harbour.Space.University/?ref=py_c
# 9544 distinct word(s) so far
# https://www.facebook.com/browse/fanned_pages/?id=398286726939216&showauxiliary=1&fanorigin=timeline_like_chaining&ref=page_internal
# 9544 distinct word(s) so far
# https://www.facebook.com/businessgazeta/
# 9596 distinct word(s) so far
# https://www.facebook.com/places/
# 9643 distinct word(s) so far
# https://www.facebook.com/places/Cem-zanatsa-v-gorode-Kazan/106456079391157/
# 9644 distinct word(s) so far
# https://www.facebook.com/privacy/explanation
# 10486 distinct word(s) so far
# https://www.facebook.com/policies?ref=pf
# 10500 distinct word(s) so far
# https://www.facebook.com/ad_campaign/landing.php?placement=pf_rhc&campaign_id=242449722530626&extra_1=auto
# 10797 distinct word(s) so far
# https://www.facebook.com/help/568137493302217
# 10798 distinct word(s) so far
# https://www.facebook.com/help/cookies?ref_type=sitefooter
# 11054 distinct word(s) so far
# https://www.facebook.com/InnopolisU/photos/pb.398286726939216.-2207520000../3139240612843800/?type=3&eid=ARB62BpSaweTk-AY2Q36o-tEf_lIfj5jjklj0byOHtqDxK4WWDaQpyK1SabidnODpq3cYiGkRTgagGD1
# 11054 distinct word(s) so far
# https://www.facebook.com/InnopolisU/photos/pb.398286726939216.-2207520000../3134361563331705/?type=3&eid=ARAfe4UgCPitsSzWMN9etYquL7vNn9SvuZzokD8dC3B2ByeCQ0IdPyLaAhKD6tpB7MTsKqbypO1xUPmR
# 11054 distinct word(s) so far
# https://www.facebook.com/InnopolisU/photos/pb.398286726939216.-2207520000../3129271113840750/?type=3&eid=ARDv9-ShF1BH63pWNZBeFq2UxbMEZ1O9uNysWmO_GDEIgTDzRMPA_Qr91jBHNcXalfIE-V92arkZ04LK
# 11054 distinct word(s) so far
# https://www.facebook.com/InnopolisU/photos/
# 11054 distinct word(s) so far
# https://www.facebook.com/InnopolisU/videos/308501133103588/
# 11091 distinct word(s) so far
# https://www.facebook.com/InnopolisU/videos/463547021210730/
# 11092 distinct word(s) so far
# https://www.facebook.com/InnopolisU/videos/1207109349390279/
# 11092 distinct word(s) so far
# https://www.facebook.com/InnopolisU/videos/
# 11092 distinct word(s) so far
# https://vk.com/photo-56385969_457245330?rev=1&from=profile
# 11093 distinct word(s) so far
# https://vk.com/login?to=aW5ub3BvbGlzdQ--
# 11097 distinct word(s) so far
# https://vk.com/away.php?to=http%3A%2F%2Funiversity.innopolis.ru
# 11097 distinct word(s) so far
# https://maps.google.com/?q=55.753352%2C48.743438
# 11099 distinct word(s) so far
# https://vk.com/attachments?act=attach_money&target=mail-56385969
# https://vk.com/@innopolisu
# 11141 distinct word(s) so far
# https://vk.com/innopolisu?act=members
# 11141 distinct word(s) so far
# https://vk.com/innopolisu?menu_opened#menu
# 11141 distinct word(s) so far
# https://vk.com/albums-56385969
# 11167 distinct word(s) so far
# https://vk.com/board56385969
# 11184 distinct word(s) so far
# https://vk.com/videos-56385969
# 11232 distinct word(s) so far
# https://vk.com/innopolisu?act=links
# 11232 distinct word(s) so far
# https://vk.com/innopolisu?act=contacts
# 11232 distinct word(s) so far
# https://vk.com/wall?act=toggle_subscribe&owner_id=-56385969&subscribe=1&from=group&hash=735acc0bd043f16225
# https://vk.com/fave?act=add_group&reference=profile&gid=56385969&hash=f96968bed58498c34e
# 11232 distinct word(s) so far
# https://vk.com/innopolisu?search=1
# 11232 distinct word(s) so far
# https://vk.com/reports?act=add_community&group_id=56385969&hash=6e8e3147f07913326f
# https://vk.com/innopolisu?own=0#wall
# 11232 distinct word(s) so far
# https://vk.com/innopolisu?own=1#wall
# 11232 distinct word(s) so far
# https://vk.com/innopolisu?from=group
# 11232 distinct word(s) so far
# https://vk.com/wall-56385969_10180
# 11233 distinct word(s) so far
# https://vk.com/away.php?to=https%3A%2F%2Fgeekz.ru%2Fconf_innopolis&post=-56385969_10180
# 11233 distinct word(s) so far
# https://vk.com/photo-56385969_457245506?rev=1&post=-56385969_10180&from=group
# 11237 distinct word(s) so far
# https://vk.com/like?act=add&object=wall-56385969_10180&from=innopolisu&hash=38fb984c213d4b945a&one=0
# https://vk.com/like?act=publish&object=wall-56385969_10180&from=innopolisu
# https://vk.com/wall-56385969_10177
# 11241 distinct word(s) so far
# https://vk.com/dovuziu?from=group
# 11371 distinct word(s) so far
# https://vk.com/wall-175449549_2997
# 11382 distinct word(s) so far
# https://vk.com/away.php?to=https%3A%2F%2Fvk.cc%2FbXn6QB&post=-56385969_10177
# 11382 distinct word(s) so far
# https://vk.com/feed?section=search&q=%23itschool_innopolis
# 11382 distinct word(s) so far
# https://vk.com/photo-175449549_457254458?list=wall-56385969_10177&from=group
# 11383 distinct word(s) so far
# https://vk.com/like?act=add&object=wall-56385969_10177&from=innopolisu&hash=32201f20d7f06bf488&one=0
# https://vk.com/like?act=publish&object=wall-56385969_10177&from=innopolisu
# https://vk.com/wall-56385969_10174
# 11385 distinct word(s) so far
# https://vk.com/away.php?to=http%3A%2F%2Fincommon.ru&post=-56385969_10174
# 11385 distinct word(s) so far
# https://vk.com/photo-56385969_457245505?rev=1&post=-56385969_10174&from=group
# 11385 distinct word(s) so far
# https://vk.com/like?act=add&object=wall-56385969_10174&from=innopolisu&hash=5a51955b186d5808be&one=0
# https://vk.com/like?act=publish&object=wall-56385969_10174&from=innopolisu
# https://vk.com/wall-56385969_10164
# 11385 distinct word(s) so far
# https://vk.com/photo-56385969_457245503?rev=1&post=-56385969_10164&from=group
# 11385 distinct word(s) so far
# https://vk.com/like?act=add&object=wall-56385969_10164&from=innopolisu&hash=a94aba85278204fa26&one=0
# https://vk.com/like?act=publish&object=wall-56385969_10164&from=innopolisu
# https://vk.com/wall-56385969_10163
# 11386 distinct word(s) so far
# https://vk.com/wall-175449549_2976
# 11398 distinct word(s) so far
# https://vk.com/feed?section=search&q=%23DovuzInnopolis
# 11398 distinct word(s) so far
# https://vk.com/feed?section=search&q=%23%D0%94%D0%BE%D0%B2%D1%83%D0%B7%D0%98%D0%BD%D0%BD%D0%BE%D0%BF%D0%BE%D0%BB%D0%B8%D1%81
# 11398 distinct word(s) so far
# https://vk.com/feed?section=search&q=%23InnopolisU
# 11398 distinct word(s) so far
# https://vk.com/@dovuziu-mechty-sbyvautsya-shkolniki-so-vsei-rossii-proveli-kanikuly
# 11624 distinct word(s) so far
# https://vk.com/like?act=add&object=wall-56385969_10163&from=innopolisu&hash=35a3409490ef43e216&one=0
# https://vk.com/like?act=publish&object=wall-56385969_10163&from=innopolisu
# https://vk.com/innopolisu?offset=5&own=1#posts
# 11624 distinct word(s) so far
# https://www.youtube.com/
# 11624 distinct word(s) so far
# https://www.youtube.com/about/
# 11680 distinct word(s) so far
# https://www.youtube.com/about/press/
# 11763 distinct word(s) so far
# https://www.youtube.com/about/copyright/
# 11876 distinct word(s) so far
# https://www.youtube.com/t/contact_us/
# 11951 distinct word(s) so far
# https://www.youtube.com/creators/
# 11956 distinct word(s) so far
# https://www.youtube.com/ads/
# 12009 distinct word(s) so far
# https://developers.google.com/youtube
# 12037 distinct word(s) so far
# https://www.youtube.com/t/terms
# 12737 distinct word(s) so far
# https://policies.google.com/privacy?hl=ru
# 13695 distinct word(s) so far
# https://www.youtube.com/about/policies/
# 13773 distinct word(s) so far
# https://www.youtube.com/howyoutubeworks?utm_campaign=ytgen&utm_source=ythp&utm_medium=LeftNav&utm_content=txt&u=https%3A%2F%2Fwww.youtube.com%2Fhowyoutubeworks%3Futm_source%3Dythp%26utm_medium%3DLeftNav%26utm_campaign%3Dytgen
# 13787 distinct word(s) so far
# https://www.youtube.com/new
# 13787 distinct word(s) so far
# https://habr.com/ru/
# 14554 distinct word(s) so far
# https://habr.com/
# 14554 distinct word(s) so far
# https://qna.habr.com?utm_source=habr&utm_medium=habr_top_panel
# 14629 distinct word(s) so far
# https://career.habr.com?utm_source=habr&utm_medium=habr_top_panel
# 14945 distinct word(s) so far
# https://freelance.habr.com?utm_source=habr&utm_medium=habr_top_panel
# 15050 distinct word(s) so far
# https://habr.com/sandbox/start/
# 15246 distinct word(s) so far
# https://u.habr.com/fuji-review
# 16283 distinct word(s) so far
# https://habr.com/ru/top/
# 16574 distinct word(s) so far
# https://habr.com/ru/flows/develop/
# 16619 distinct word(s) so far
# https://habr.com/ru/flows/admin/
# 16901 distinct word(s) so far
# https://habr.com/ru/flows/design/
# 17392 distinct word(s) so far
# https://habr.com/ru/flows/management/
# 17641 distinct word(s) so far
# https://habr.com/ru/flows/marketing/
# 18072 distinct word(s) so far
# https://habr.com/ru/flows/popsci/
# 18130 distinct word(s) so far
# https://habr.com/ru/auth/login/
# 18131 distinct word(s) so far
# https://habr.com/ru/auth/register/
# 18133 distinct word(s) so far
# https://habr.com/ru/users/T-Fazullin/
# 18138 distinct word(s) so far
# https://habr.com/ru/info/help/karma/
# 18378 distinct word(s) so far
# https://habr.com/ru/info/help/karma/#rating
# 18378 distinct word(s) so far
# https://habr.com/ru/users/T-Fazullin/subscription/followers/
# 18381 distinct word(s) so far
# https://habr.com/ru/users/T-Fazullin/subscription/follow/
# 18382 distinct word(s) so far
# https://habr.com/users/T-Fazullin/
# 18382 distinct word(s) so far
# https://habr.com/ru/users/t-fazullin/
# 18382 distinct word(s) so far
# https://habr.com/ru/users/t-fazullin/comments/
# 18389 distinct word(s) so far
# https://habr.com/ru/users/t-fazullin/favorites/
# 18391 distinct word(s) so far
# 'utf-8' codec can't decode byte 0xed in position 141319: invalid continuation byte
# https://habr.com/ru/company/innopolis_university/
# 18392 distinct word(s) so far
# https://habr.com/ru/hub/career/
# 18851 distinct word(s) so far
# 'utf-8' codec can't decode byte 0xed in position 141319: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 141319: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 99732: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 99732: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 99732: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 97724: invalid continuation byte
# https://habr.com/ru/hub/geo/
# 19372 distinct word(s) so far
# https://habr.com/ru/hub/cloud_services/
# 19816 distinct word(s) so far
# https://habr.com/ru/info/help/karma/#recovery
# 19816 distinct word(s) so far
# https://goo.gl/forms/9eQ9EKWj7EvghNvY2
# 19820 distinct word(s) so far
# 'utf-8' codec can't decode byte 0xed in position 97724: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 97724: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 148035: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 148035: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 148035: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 114564: invalid continuation byte
# https://habr.com/ru/hub/study/
# 20087 distinct word(s) so far
# 'utf-8' codec can't decode byte 0xed in position 114564: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 114564: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 185726: invalid continuation byte
# https://habr.com/ru/hub/infosecurity/
# 20403 distinct word(s) so far
# http://uk.businessinsider.com/7-important-cybersecurity-companies-2015-5?op=1
# 20582 distinct word(s) so far
# https://apply.innopolis.ru/master/the-development-of-secure-systems-and-networks/
# 20659 distinct word(s) so far
# 'utf-8' codec can't decode byte 0xed in position 185726: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 185726: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 95407: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 95407: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 95407: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 96083: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 96083: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 103604: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 103604: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 103604: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 95578: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 95578: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 95578: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 114894: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 114894: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 114894: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 227653: invalid continuation byte
# https://habr.com/ru/hub/hackathons/
# 21028 distinct word(s) so far
# https://habr.com/ru/hub/robo_dev/
# 21563 distinct word(s) so far
# 'utf-8' codec can't decode byte 0xed in position 227653: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 227653: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 141967: invalid continuation byte
# https://habr.com/ru/hub/bigdata/
# 21908 distinct word(s) so far
# 'utf-8' codec can't decode byte 0xed in position 141967: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 141967: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 142231: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 115790: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 142231: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 142231: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 95636: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 95636: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 95636: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 214400: invalid continuation byte
# https://habr.com/ru/hub/programming/
# 22213 distinct word(s) so far
# https://cacm.acm.org/blogs/blog-cacm/211080-null-pointer-crashes-no-more/fulltext
# 'utf-8' codec can't decode byte 0xed in position 214400: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 214400: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 112424: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 112424: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 112424: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 102695: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 102695: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 102695: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 134144: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 134144: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 134144: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 104712: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 104712: invalid continuation byte
# 'utf-8' codec can't decode byte 0xed in position 104712: invalid continuation byte
# https://habr.com/ru/users/
# 22563 distinct word(s) so far
# https://habr.com/ru/posts/top/
# 22563 distinct word(s) so far
# https://habr.com/ru/news/
# 22856 distinct word(s) so far
# https://habr.com/ru/hubs/
# 22953 distinct word(s) so far
# https://habr.com/ru/companies/
# 22971 distinct word(s) so far
# https://habr.com/ru/sandbox/
# 23380 distinct word(s) so far
# https://habr.com/ru/docs/help/
# 23526 distinct word(s) so far
# https://habr.com/ru/docs/authors/
# 23567 distinct word(s) so far
# https://habr.com/ru/docs/companies/
# 23590 distinct word(s) so far
# https://habr.com/ru/docs/docs/
# 23620 distinct word(s) so far
# https://account.habr.com/info/agreement/?hl=ru_RU
# 24002 distinct word(s) so far
# https://account.habr.com/info/confidential/?hl=ru_RU
# 24195 distinct word(s) so far
# https://tmtm.ru/services/advertising/
# 24245 distinct word(s) so far
# https://tmtm.ru/services/corpblog/
# 24300 distinct word(s) so far
# https://tmtm.ru/services/content/
# 24308 distinct word(s) so far
# https://tmtm.ru/workshops/
# 24321 distinct word(s) so far
# https://habr.com/ru/megaprojects/
# 24582 distinct word(s) so far
# https://habr.market/
# 24608 distinct word(s) so far
# https://company.habr.com/
# 24613 distinct word(s) so far
# https://habr.com/ru/about/
# 24658 distinct word(s) so far
# https://habr.com/ru/feedback/
# 24680 distinct word(s) so far
# https://m.habr.com/ru?mobile=yes
# 24685 distinct word(s) so far
# https://twitter.com/habr_com
# https://www.facebook.com/habrahabr.ru
# 24730 distinct word(s) so far
# https://vk.com/habr
# 24749 distinct word(s) so far
# https://telegram.me/habr_com
# 24750 distinct word(s) so far
# https://www.youtube.com/channel/UCd_sTwKqVrweTt4oAKY5y4w
# 24750 distinct word(s) so far
# https://zen.yandex.ru/habr
# 24792 distinct word(s) so far
# https://apply.innopolis.university/en/about/
# https://apply.innopolis.university/en/board/
# https://apply.innopolis.university/en/team/
# https://apply.innopolis.university/en/team-structure/
# https://apply.innopolis.university/en/education-academics/
# https://apply.innopolis.university/en/techcenters/
# https://apply.innopolis.university/en/faculty/
# https://apply.innopolis.university/en/campus/
# https://apply.innopolis.university/en/contacts/
# https://apply.innopolis.university/en/datascience
# 24828 distinct word(s) so far
# https://apply.innopolis.university/en/razrabotka-bezopasnyh-sistem-i-setej/
# 24883 distinct word(s) so far
# https://apply.innopolis.university/en/development2/
# 24928 distinct word(s) so far
# https://apply.innopolis.university/en/robotics/
# 24936 distinct word(s) so far
# https://apply.innopolis.university/en/research/
# https://apply.innopolis.university/en/Labofoperatingsystemsprogramminglanguagesandcompilers/
# https://apply.innopolis.university/en/Labofsoftwareandserviceengineering/
# https://apply.innopolis.university/en/labofindustrializingsoftwareproduction /
# https://apply.innopolis.university/en/Labofdataanalysisandbioinformatics/
# https://apply.innopolis.university/en/Labofartificialintelligenceingamedevelopment2/
# https://apply.innopolis.university/en/labofdataanalysisandmachinelearningintheoilandgasindustry/
# https://apply.innopolis.university/en/Labofmachinelearningandknowledgerepresentation/
# https://apply.innopolis.university/en/Labofcyberphysicalsystems/
# https://apply.innopolis.university/en/networksandblockchainlab/
# https://apply.innopolis.university/en/laboratoriya-intellektualnyh-robototekhnicheskih-sistem/
# https://apply.innopolis.university/en/activity/
# https://apply.innopolis.university/en/podderzhka-innovacionnoj-deyatelnosti/
# https://apply.innopolis.university/en/internationalpartners/
# https://apply.innopolis.university/en/organizatsiya-i-provedenie-meropriyatiy/
# https://apply.innopolis.university/en/search/
# https://apply.innopolis.university/profile/
# https://apply.innopolis.university/search/
# https://apply.innopolis.ru/en/get-in/
# 25141 distinct word(s) so far
# HTTPSConnectionPool(host='video.innopolis.university', port=443): Max retries exceeded with url: /vod/2020/Webinar_Master_Software_Engineering.mp4/embed.html (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faea61b3e50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# HTTPSConnectionPool(host='video.innopolis.university', port=443): Max retries exceeded with url: /vod/2020/Webinar_Master_Security_and_Network_Engineering.mov/embed.html (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faea61b3ee0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# HTTPSConnectionPool(host='video.innopolis.university', port=443): Max retries exceeded with url: /vod/2020/Webinar_Master_Robotics.mov/embed.html (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faea61ad550>: Failed to establish a new connection: [Errno 61] Connection refused'))
# HTTPSConnectionPool(host='video.innopolis.university', port=443): Max retries exceeded with url: /vod/2020/Webinar_Master_Data_Science.mov/embed.html (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7faea61add90>: Failed to establish a new connection: [Errno 61] Connection refused'))
# https://apply.innopolis.university/en/#block2149
# 25141 distinct word(s) so far
# https://www.ets.org/s/cv/toefl/at-home/
# 25165 distinct word(s) so far
# https://englishtest.duolingo.com/
# 25165 distinct word(s) so far
# http://nic.gov.ru/en/proc/nic/legalize
# 25227 distinct word(s) so far
# https://drive.google.com/file/d/10spw7SYKomHSyWuaNMWMl3-t_OiiR-qg/view
# 25227 distinct word(s) so far
# https://drive.google.com/file/d/193kK6kV0RAzdp_wRksSJy9a9y1s0gMaE/view
# 25227 distinct word(s) so far
# https://drive.google.com/file/d/1YYhSiVTm6bxxeBt0fv7rbrMdgU0C2e2_/view
# 25227 distinct word(s) so far
# https://drive.google.com/file/d/1HATau9H2J2rJbC45o2EiREsGDKpNODA1/view
# 25227 distinct word(s) so far
# https://innopolis.university/sveden/apply/
# 25315 distinct word(s) so far
# https://www.embassy-worldwide.com/country/russia/?__cf_chl_jschl_tk__=a94cd95afa1311b39144c68ade05bb4c404c36e0-1603284143-0-AdT5wLmOm0W3vCpGYOe8JBgEGI_UYrAl9mWAr7wF22c8uVpnkbbSHOvIwBv5Iye4w3P-miBYqs-aStGmVo93k7jYCS4NQJ4cBWodhvlIsetlsYyQkaTTq_1OvbDiIsbarbVcfHyi_KH0wJDIB4Z1JSPevDKQ6oR5rH2pop3jbhEktZbCT0kRVDrWxej3fichPVhNcCSMyJo5Z_HfpLkGjswRihnDmrFYGShrU_nM8GeNxsvd1lq4tor0CCi4CDY-BmwRNtNskMF1TZM7sHN7KiYYjvEUqpo8sdK-5_o9tJQx
# https://innopolis.com/en/
# 25377 distinct word(s) so far
# decode() argument 'encoding' must be str, not None
# https://corporate.innopolis.university/outsourcingrd/
# 25402 distinct word(s) so far
# https://corporate.innopolis.university/education/
# 25447 distinct word(s) so far
# https://corporate.innopolis.university/technologicalaudit/
# 25528 distinct word(s) so far
# https://corporate.innopolis.university/stratsession/
# 25638 distinct word(s) so far
# https://corporate.innopolis.university/podgotovkakadrov/
# 25713 distinct word(s) so far
# https://corporate.innopolis.university/en/
# 25742 distinct word(s) so far
# https://innopolis.university/organizatsiya-i-provedenie-meropriyatiy/
# 25884 distinct word(s) so far
# http://spec.innopolis.university/case/innopolis?utm_source=iusite&utm_campaign=cases
# 25992 distinct word(s) so far
# http://spec.innopolis.university/case/map?utm_source=iusite&utm_campaign=cases
# 26115 distinct word(s) so far
# http://spec.innopolis.university/case/java?utm_source=iusite&utm_campaign=cases
# 26248 distinct word(s) so far
# No connection adapters were found for 'mailto:corporate@innopolis.university'
# decode() argument 'encoding' must be str, not None
# https://corporate.innopolis.university
# 26248 distinct word(s) so far
# https://innopolis.university/about/
# 26314 distinct word(s) so far
# https://career.innopolis.university/vacancies/
# 27124 distinct word(s) so far
# https://innopolis.university/proekty/activity/
# 27146 distinct word(s) so far
# No connection adapters were found for 'tel:+78432039253'
# No connection adapters were found for 'mailto:university@innopolis.ru'
# https://innopolis.university/contacts/
# 27146 distinct word(s) so far
# http://www.innopolis.com/city/how-to-get/
# 27202 distinct word(s) so far
# No connection adapters were found for 'mailto:pr@innopolis.ru'
# https://media.innopolis.university/events/
# 27227 distinct word(s) so far
# https://innopolis.university/sveden/
# 27229 distinct word(s) so far
# https://digital.gov.ru/ru/
# 27388 distinct word(s) so far
# https://minobrnauki.gov.ru
# 27479 distinct word(s) so far
# https://www.minobrnauki.gov.ru/ru/activity/other/info_koronavirus/
# https://media.innopolis.university/?TAGS=*
# 27479 distinct word(s) so far
# https://media.innopolis.university/?TAGS=Индустрия
# 27479 distinct word(s) so far
# https://media.innopolis.university/?TAGS=Наука
# 27479 distinct word(s) so far
# https://media.innopolis.university/?TAGS=Образование
# 27479 distinct word(s) so far
# https://media.innopolis.university/?TAGS=Школа
# 27479 distinct word(s) so far
# https://media.innopolis.university/?TAGS=Студенческая жизнь
# 27479 distinct word(s) so far
# https://media.innopolis.university/?TAGS=Международное сотрудничество
# 27479 distinct word(s) so far
# https://media.innopolis.university/?TAGS=Робототехника
# 27479 distinct word(s) so far
# https://media.innopolis.university/?TAGS=Блокчейн
# 27479 distinct word(s) so far
# https://media.innopolis.university/?TAGS=Инфобез
# 27479 distinct word(s) so far
# https://media.innopolis.university/news/AI-for-med-12-2020/
# 27538 distinct word(s) so far
# https://media.innopolis.university/news/iu-smart-forest-ai/
# 27616 distinct word(s) so far
# https://media.innopolis.university/news/danaflex-ai-ui-2020/
# 27642 distinct word(s) so far
# https://media.innopolis.university/#news-page__all-news__news-container
# 27642 distinct word(s) so far
# https://media.innopolis.university/news/rffi-tsa-helper/
# 27684 distinct word(s) so far
# https://media.innopolis.university/news/digital-education-forum-final/
# 27756 distinct word(s) so far
# https://media.innopolis.university/news/aeroflot-click-2020/
# 27793 distinct word(s) so far
# https://media.innopolis.university/news/ooc-2024-80k/
# 27805 distinct word(s) so far
# https://media.innopolis.university/news/forest-monitoring-lanit/
# 27882 distinct word(s) so far
# https://media.innopolis.university/news/smart-shirt-iu/
# 27908 distinct word(s) so far
# https://media.innopolis.university/?PAGEN_2=2
# 27908 distinct word(s) so far
# https://media.innopolis.university/?PAGEN_2=3
# 27908 distinct word(s) so far
# https://media.innopolis.university/?PAGEN_2=93
# 27908 distinct word(s) so far
# https://media.innopolis.university/?PAGEN_2=94
# 27908 distinct word(s) so far
# https://m.vk.com/innopolisu
# 27908 distinct word(s) so far
# https://innopolis.university/board/
# 27944 distinct word(s) so far
# https://innopolis.university/team/
# 27945 distinct word(s) so far
# https://innopolis.university/team-structure/
# 27948 distinct word(s) so far
# https://innopolis.university/team-structure/education-academics/
# 27949 distinct word(s) so far
# https://innopolis.university/team-structure/techcenters/
# 27951 distinct word(s) so far
# https://innopolis.university/faculty/
# 28491 distinct word(s) so far
# https://career.innopolis.university
# 28605 distinct word(s) so far
# https://career.innopolis.university/corporate-life/
# 28637 distinct word(s) so far
# https://career.innopolis.university/relocation/
# 28784 distinct word(s) so far
# https://innopolis.university/campus/
# 29034 distinct word(s) so far
# https://apply.innopolis.university/open-day/
# 29044 distinct word(s) so far
# https://apply.innopolis.university/grant/
# 29075 distinct word(s) so far
# https://apply.innopolis.university/olympiad-bonus/
# 29107 distinct word(s) so far
# https://apply.innopolis.university/faq/
# 29147 distinct word(s) so far
# https://dovuz.innopolis.university/
# 29194 distinct word(s) so far
# https://dovuz.innopolis.university/about/
# 29288 distinct word(s) so far
# https://dovuz.innopolis.university/events/
# 29298 distinct word(s) so far
# https://apply.innopolis.university/bachelor/
# 29340 distinct word(s) so far
# https://apply.innopolis.university/master/
# 29348 distinct word(s) so far
# https://apply.innopolis.university/master/datascience/
# 29373 distinct word(s) so far
# https://apply.innopolis.university/master/razrabotka-bezopasnyh-sistem-i-setej/
# 29374 distinct word(s) so far
# https://apply.innopolis.university/master/robotics/
# 29395 distinct word(s) so far
# https://apply.innopolis.university/master/development/
# 29402 distinct word(s) so far
# https://apply.innopolis.university/postgraduate-study/
# 29417 distinct word(s) so far
# https://apply.innopolis.university/stud-life/
# 29491 distinct word(s) so far
# https://apply.innopolis.university/stazhirovki-i-trudoustrojstvo/
# 29584 distinct word(s) so far
# https://innopolis.university/dpo/
# 29592 distinct word(s) so far
# https://innopolis.university/dpo-courses/
# 29618 distinct word(s) so far
# https://innopolis.university/research/
# 29656 distinct word(s) so far
# https://innopolis.university/team-structure/team-faculty/
# 29663 distinct word(s) so far
# https://innopolis.university/laboratoriya-operacionnyh-sistem-yazykov-programmirovaniya-i-kompilyatorov/
# 29689 distinct word(s) so far
# https://innopolis.university/laboratoriya-programmnoy-inzhenerii/
# 29735 distinct word(s) so far
# https://innopolis.university/laboratoriya-promyshlennoj-razrabotki-po/
# 29750 distinct word(s) so far
# https://innopolis.university/laboratoriya-analiza-dannyh-i-bioinformatiki
# 29773 distinct word(s) so far
# https://innopolis.university/laboratoriya-analiza-dannyh-i-mashinnogo-obucheniya-v-neftegazovoj-otrasli
# 29821 distinct word(s) so far
# https://innopolis.university/laboratoriya-iskusstvennogo-intellekta-v-razrabotke-igr
# 29854 distinct word(s) so far
# https://innopolis.university/laboratoriya-mashinnogo-obucheniya-i-predstavleniya-dannyh
# 29901 distinct word(s) so far
# https://innopolis.university/laboratoriya-kiberfizicheskih-sistem
# 29918 distinct word(s) so far
# https://innopolis.university/laboratoriya-setej-i-tekhnologij-blokchejn
# 29933 distinct word(s) so far
# https://innopolis.university/laboratoriya-intellektualnyh-robototekhnicheskih-sistem
# 30023 distinct word(s) so far
# https://innopolis.university/publikatsii
# 30037 distinct word(s) so far
# https://innopolis.university/patenty
# 30100 distinct word(s) so far
# https://innopolis.university/portfel-proektov/
# 30182 distinct word(s) so far
# https://innopolis.university/center-blockchain2/
# 30214 distinct word(s) so far
# https://innopolis.university/centergis3/
# 30321 distinct word(s) so far
# https://innopolis.university/center-cybersecurity/
# 30424 distinct word(s) so far
# https://innopolis.university/center-ai3/
# 30480 distinct word(s) so far
# https://innopolis.university/center-oil/
# 30525 distinct word(s) so far
# https://innopolis.university/center-robotics/
# 30754 distinct word(s) so far
# https://innopolis.university/proekty/podderzhka-innovacionnoj-deyatelnosti/
# 30775 distinct word(s) so far
# https://innopolis.university/digital-economy
# 30811 distinct word(s) so far
# https://innopolis.university/sponsorship/
# 30825 distinct word(s) so far
# https://mail.innopolis.ru/
# 30828 distinct word(s) so far
# https://portal.university.innopolis.ru
# 30828 distinct word(s) so far
# https://it.university.innopolis.ru/portal
# 30838 distinct word(s) so far
# https://apply.innopolis.ru/get-in/
# 31044 distinct word(s) so far
# https://my.university.innopolis.ru/
# 31045 distinct word(s) so far
# https://dovuz.innopolis.university/login/
# 31051 distinct word(s) so far
# No connection adapters were found for 'mailto:it@innopolis.ru'
# https://robotics.innopolis.university/en/
# 31052 distinct word(s) so far
# No connection adapters were found for 'mailto:office@digital.gov.ru'
# http://mzio.tatarstan.ru
# 31137 distinct word(s) so far
# No connection adapters were found for 'mailto:mzio@tatar.ru'
# https://innopolis.university/en/team-director/
# 31154 distinct word(s) so far
# https://innopolis.university/en/team-rector/
# 31158 distinct word(s) so far
# https://innopolis.university/en/team-faculty/
# 31158 distinct word(s) so far
# https://innopolis.university/en/team-faculty2/
# 31160 distinct word(s) so far
# https://innopolis.university/en/team-academicpolicy/
# 31164 distinct word(s) so far
# https://innopolis.university/en/centerfortechnologiesinroboticsandmechatronicscomponents/
# 31190 distinct word(s) so far
# https://innopolis.university/en/Centerforinformationsecurity/
# 31222 distinct word(s) so far
# https://innopolis.university/en/centerforgeographicinformationsystems /
# 31239 distinct word(s) so far
# https://innopolis.university/en/Leadingresearchcenterforblockchaintechnology/
# 31259 distinct word(s) so far
# https://innopolis.university/en/centerforartificialintelligence/
# 31270 distinct word(s) so far
# https://innopolis.university/en/centerforpoilandgastechnology /
# 31275 distinct word(s) so far
# https://innopolis.university/professor/giancarlo-succi/
# 31275 distinct word(s) so far
# https://innopolis.university/en/labofindustrializingsoftwareproduction%20/
# 31275 distinct word(s) so far
# https://innopolis.university/professor/manuel-mazzara/
# 31275 distinct word(s) so far
# https://innopolis.university/professor/ilya-afanasyev/
# 31275 distinct word(s) so far
# https://innopolis.university/professor/vladimir-ivanov-/
# 31275 distinct word(s) so far
# https://innopolis.university/professor/andrey-sadovykh-/
# 31275 distinct word(s) so far
# https://innopolis.university/professor/eugene-zuev/
# 31275 distinct word(s) so far
# https://innopolis.university/professor/nikolay-shilov/
# 31275 distinct word(s) so far
# https://innopolis.university/professor/rasheed-hussain/
# 31275 distinct word(s) so far
# https://innopolis.university/professor/ahsan-kazmi/
# 31275 distinct word(s) so far
# https://innopolis.university/professor/aleksander-klimchik/
# 31275 distinct word(s) so far
# https://innopolis.university/professor/igor-gaponov/
# 31275 distinct word(s) so far
# https://innopolis.university/professor/mohammad-reza-bahrami-/
# 31275 distinct word(s) so far
# https://innopolis.university/professor/muhammad-fahim-/
# 31275 distinct word(s) so far
# https://innopolis.university/professor/alma-oracevic/
# 31275 distinct word(s) so far
# https://innopolis.university/professor/artem-burmyakov/
# 31275 distinct word(s) so far
# https://innopolis.university/professor/adil-khan/
# 31275 distinct word(s) so far
# https://innopolis.university/professor/sergey-gorodetskiy-/
# 31275 distinct word(s) so far
# https://innopolis.university/professor/joseph-brown/
# 31275 distinct word(s) so far
# https://innopolis.university/professor/yaroslav-kholodov/
# 31275 distinct word(s) so far
# https://innopolis.university/professor/rabab-marouf-/
# 31275 distinct word(s) so far
# https://innopolis.university/professor/sergei-kladko/
# 31275 distinct word(s) so far
# https://innopolis.university/professor/kirill-poletkin/
# 31275 distinct word(s) so far
# https://innopolis.university/professor/guzel-fazlyeva/
# 31275 distinct word(s) so far
# https://innopolis.university/professor/sergey-savin/
# 31275 distinct word(s) so far
# http://www.researchgate.net/profile/Sergei_Savin2
# 31957 distinct word(s) so far
# http://orcid.org/0000-0001-7954-3144
# 31959 distinct word(s) so far
# http://www.scopus.com/authid/detail.uri?authorId=55978984900
# http://scholar.google.ru/citations?user=sVjTfqEAAAAJ&hl=en
# 32051 distinct word(s) so far
# https://old.innopolis.university/en/about/city
# 32051 distinct word(s) so far
# https://old.innopolis.university/en/about/structure
# 32051 distinct word(s) so far
# https://old.innopolis.university/en/about/job
# 32051 distinct word(s) so far
# https://old.innopolis.university/en/about/professors/
# 32051 distinct word(s) so far
# decode() argument 'encoding' must be str, not None
# https://innopolis.university/professor/stanislav-protasov/
# 32051 distinct word(s) so far
# https://innopolis.university/professor/luiz-dzhonata-pires-de-arauzhu/
# 32051 distinct word(s) so far
# https://innopolis.university/professor/aleksandr-naumchev/
# 32051 distinct word(s) so far
# https://english.nsu.ru/
# 32099 distinct word(s) so far
# https://www.cmu.edu/
# 32136 distinct word(s) so far
# http://thesesups.ups-tlse.fr/4468/
# 32332 distinct word(s) so far
# https://en.univ-toulouse.fr/
# 32373 distinct word(s) so far
# https://university.innopolis.ru/en/research/personal/bertrand-meyer/
# https://jmbruel.github.io/smartjmb/
# 32376 distinct word(s) so far
# https://university.innopolis.ru/en/research/itsd/selab
# No connection adapters were found for 'mailto:a.naumchev@innopolis.ru'
# https://dblp.uni-trier.de/pers/hd/n/Naumchev:Alexandr
# 32492 distinct word(s) so far
# https://publons.com/researcher/1472116/alexandr-naumchev/
# 32515 distinct word(s) so far
# https://www.scopus.com/authid/detail.uri?authorId=57190306849
# https://innopolis.university/professor/leonid-merkin/
# 32515 distinct word(s) so far
# https://innopolis.university/en/lab-of-data-analysis-and-financial-technologies/
# https://innopolis.university/professor/artem-kruglov/
# 32515 distinct word(s) so far
# https://innopolis.university/professor/georgiy-gelvanovskiy/
# ...
# https://career.innopolis.university/success-stories/julia-kazaeva/
# 32571 distinct word(s) so far
# https://career.innopolis.university/success-stories/farid-gainullin/
# 32571 distinct word(s) so far
# https://career.innopolis.university/success-stories/salimzhan-gafurov-en/
# 32571 distinct word(s) so far
# No connection adapters were found for 'mailto:resume@innopolis.ru'
# http://www.innopolis.com/resident/sport/sports-complex/
# 32719 distinct word(s) so far
# http://www.innopolis.com/resident/sport/jogging-routes/
# 32738 distinct word(s) so far
# No connection adapters were found for 'mailto:hoteluni@innopolis.ru'
# http://hotel.innopolis.university/
# 32783 distinct word(s) so far
# No connection adapters were found for 'mailto:dovuz@innopolis.university'
# No connection adapters were found for 'mailto:admissions@innopolis.ru'
# decode() argument 'encoding' must be str, not None
# decode() argument 'encoding' must be str, not None
# decode() argument 'encoding' must be str, not None
# https://apply.innopolis.university/en/datascience/
# 32783 distinct word(s) so far
# https://apply.innopolis.university/en/grant/#block2238
# 32783 distinct word(s) so far
# http://www.campuslife.innopolis.ru/events
# 32838 distinct word(s) so far
# http://www.campuslife.innopolis.ru/clubs
# 32852 distinct word(s) so far
# http://www.campuslife.innopolis.ru/innopoints
# 32864 distinct word(s) so far
# https://innopolis.university/en/international-relations-office
# 32864 distinct word(s) so far
# http://innopolis.ru/
# 32891 distinct word(s) so far
# https://innopolis.university/success-stories/viktor-vasilenko/
# 32891 distinct word(s) so far
# https://innopolis.university/success-stories/anastasia-kozar/
# 32891 distinct word(s) so far
# https://innopolis.university/public/files/pdf.pdf
# No connection adapters were found for 'mailto:international@innopolis.university'
# https://innopolis.university/en/research/null
# https://apply.innopolis.university/en/stazhirovki-i-trudoustrojstvo/
# No connection adapters were found for 'mailto:e.zuev@innopolis.ru'
# No connection adapters were found for 'mailto:n.shilov@innopolis.ru'
# No connection adapters were found for 'mailto:g.succi@innopolis.ru'
# No connection adapters were found for 'mailto:ya.kholodov@innopolis.ru'
# No connection adapters were found for 'mailto:j.brown@innopolis.ru'
# No connection adapters were found for 'mailto:i.konuhov@innopolis.ru'
# No connection adapters were found for 'mailto:a.khan@innopolis.ru'
# No connection adapters were found for 'mailto:a.sillitti@innopolis.ru'
# No connection adapters were found for 'mailto:r.hussain@innopolis.ru'
# No connection adapters were found for 'mailto:i.gaponov@innopolis.ru'
# https://innopolis.university/en/activity/#2384
# 32891 distinct word(s) so far
# https://innopolis.university/digital-economy/
# 32891 distinct word(s) so far
# https://innopolis.university/en/organizatsiya-i-provedenie-meropriyatiy/#block2342
# 32891 distinct word(s) so far
# https://media.innopolis.university/en/events/zimnyaya-shkola-olimpiadnoy-podgotovki-po-matematike-/
# 32891 distinct word(s) so far
# https://media.innopolis.university/en/events/intensivnaya-onlayn-podgotovka-k-ege-po-fizike-ot-universiteta-innopolis-3-modul/
# 32891 distinct word(s) so far
# https://media.innopolis.university/en/events/intensivnaya-onlayn-podgotovka-k-ege-po-informatike-ot-universiteta-innopolis-3-modul/
# 32891 distinct word(s) so far
# https://media.innopolis.university/en/events/intensivnaya-onlayn-podgotovka-k-ege-po-matematike-ot-universiteta-innopolis-3-modul/
# 32891 distinct word(s) so far
# https://media.innopolis.university/en/events/innopolis-open-po-informatsionnoy-bezopasnosti/
# 32891 distinct word(s) so far
# No connection adapters were found for 'mailto:events@innopolis.ru'
# https://apply.innopolis.university
# 32891 distinct word(s) so far
# https://dovuz.innopolis.university
# 32891 distinct word(s) so far
# https://media.innopolis.university/events/zimnyaya-shkola-olimpiadnoy-podgotovki-po-matematike-/
# 32901 distinct word(s) so far
# https://media.innopolis.university/events/intensivnaya-onlayn-podgotovka-k-ege-po-fizike-ot-universiteta-innopolis-3-modul/
# 32907 distinct word(s) so far
# https://media.innopolis.university/events/intensivnaya-onlayn-podgotovka-k-ege-po-informatike-ot-universiteta-innopolis-3-modul/
# 32907 distinct word(s) so far
# https://media.innopolis.university/events/intensivnaya-onlayn-podgotovka-k-ege-po-matematike-ot-universiteta-innopolis-3-modul/
# 32907 distinct word(s) so far
# https://media.innopolis.university/events/innopolis-open-po-informatsionnoy-bezopasnosti/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/en/board/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/en/team/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/en/team-structure/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/en/education-academics/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/en/techcenters/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/en/faculty/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/en/campus/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/en/contacts/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/en/datascience
# https://university.innopolis.ru/en/razrabotka-bezopasnyh-sistem-i-setej/
# https://university.innopolis.ru/en/development2/
# https://university.innopolis.ru/en/robotics/
# https://university.innopolis.ru/en/research/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/en/Labofoperatingsystemsprogramminglanguagesandcompilers/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/en/Labofsoftwareandserviceengineering/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/en/labofindustrializingsoftwareproduction /
# 32909 distinct word(s) so far
# https://university.innopolis.ru/en/Labofdataanalysisandbioinformatics/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/en/Labofartificialintelligenceingamedevelopment2/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/en/labofdataanalysisandmachinelearningintheoilandgasindustry/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/en/Labofmachinelearningandknowledgerepresentation/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/en/Labofcyberphysicalsystems/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/en/networksandblockchainlab/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/en/laboratoriya-intellektualnyh-robototekhnicheskih-sistem/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/en/activity/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/en/podderzhka-innovacionnoj-deyatelnosti/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/en/internationalpartners/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/en/organizatsiya-i-provedenie-meropriyatiy/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/en/search/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/
# 32909 distinct word(s) so far
# https://university.innopolis.ru/profile/
# https://university.innopolis.ru/search/
# 32909 distinct word(s) so far
# decode() argument 'encoding' must be str, not None
# http://www.campuslife.innopolis.ru/handbook2020
# 33055 distinct word(s) so far
# http://www.campuslife.innopolis.ru/services
# 33057 distinct word(s) so far
# http://www.campuslife.innopolis.ru/aboutsu
# 33058 distinct word(s) so far
# https://bit.ly/2IX3Nx9
# 33099 distinct word(s) so far
# http://campuslife.innopolis.ru/innostudents
# 33114 distinct word(s) so far
# http://campuslife.innopolis.ru/battle_rage
# 33139 distinct word(s) so far
# https://t.me/joinchat/DjhyZkBN-FmZStxTB40qwQ
# 33141 distinct word(s) so far
# https://docs.google.com/document/d/1D23NYEsWNRexYgeYT8Om3oaNVyGealNYfqOaYlqV4xs/edit
# 33148 distinct word(s) so far
# http://www.campuslife.innopolis.ru/volunteering
# 33149 distinct word(s) so far
# http://www.campuslife.innopolis.ru/tutorship
# 33165 distinct word(s) so far
# http://www.campuslife.innopolis.ru/studentreps
# 33178 distinct word(s) so far
# https://www.facebook.com/InnopolisStudents
# 33178 distinct word(s) so far
# https://vk.com/innostudents
# 33204 distinct word(s) so far
# https://www.instagram.com/innostudents/
# 33204 distinct word(s) so far
# http://t.me/StudentAffairs_bot
# 33204 distinct word(s) so far
# https://tilda.cc/?upm=686376
# 33482 distinct word(s) so far
# https://us02web.zoom.us/j/9660990045?pwd=haAZQtiWaT-BVj-FamfQPy-KdnNBvQ
# 33482 distinct word(s) so far
# https://us02web.zoom.us/j/86924417470?pwd=cWpHUlk4OG5BcVNjek94Qk9mMEFjQT09
# 33482 distinct word(s) so far
# https://us02web.zoom.us/j/82115193290?pwd=aStDSVpXUnV5Q0JwZXB3Lys4YmJQUT09
# 33482 distinct word(s) so far
# https://us02web.zoom.us/j/81023939550?pwd=ZHZka0hGTVh4RWFoOUZ3V3lESjVYUT09
# 33482 distinct word(s) so far
# https://us02web.zoom.us/j/84204806112?pwd=Q0ROZkw3bmVGUTB2Q3pYRjFPRWk0UT09
# 33482 distinct word(s) so far
# https://media.innopolis.university/en/news/kuka-robotics-innopolis-university-cooperation/
# 33489 distinct word(s) so far
# https://media.innopolis.university/en/news/postgres-laboratory-innopolis-university/
# 33495 distinct word(s) so far
# https://media.innopolis.university/en/news/VisionHack/
# 33525 distinct word(s) so far
# https://media.innopolis.university/?TAGS=Research
# 33525 distinct word(s) so far
# https://cs.gssi.it/devops2020/
# 33563 distinct word(s) so far
# https://media.innopolis.university/en/news/x5-iu/
# 33584 distinct word(s) so far
# https://media.innopolis.university/en/news/innopolis-university-gazprom/
# 33591 distinct word(s) so far
# https://media.innopolis.university/en/news/iu-cluster-ulyanovsk/
# 33594 distinct word(s) so far
# http://apply.innopolis.ru/en/it-degree/
# 33594 distinct word(s) so far
# http://apply.innopolis.ru/en/get-in/guidelines/
# 33594 distinct word(s) so far
# https://pruffme.com/landing/u139557/applyDec24
# 33595 distinct word(s) so far
# https://media.innopolis.university/?TAGS=Education
# 33595 distinct word(s) so far
# https://olymp.innopolis.ru/en/ooui/2020/
# 33596 distinct word(s) so far
# No connection adapters were found for 'mailto:olymp@innopolis.ru'
# No connection adapters were found for 'mailto:iu.ctf@innopolis.ru'
# https://media.innopolis.university/en/news/data-science-camp/
# 33604 distinct word(s) so far
# https://media.innopolis.university/en/news/final-ejoi-2018/
# 33621 distinct word(s) so far
# https://www.riverpublishers.com/books.php
# 33865 distinct word(s) so far
# https://apply.innopolis.ru/en/master/
# https://apply.innopolis.ru/en/it-degree/
# 33865 distinct word(s) so far
# https://apply.innopolis.ru/en/get-in/guidelines/
# 33865 distinct word(s) so far
# https://www.facebook.com/InnopolisU/
# 33865 distinct word(s) so far
# https://twitter.com/InnopolisU/status/974558530815500288
# HTTPSConnectionPool(host='www.linkedin.com', port=443): Max retries exceeded with url: /company/innopolis-university/ (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fae8beeecd0>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# No connection adapters were found for 'mailto:admissions@Innopolis.ru'
# https://university.innopolis.ru/en/research/self-driven-school/
# https://apply.innopolis.ru/en/
# 33865 distinct word(s) so far
# No connection adapters were found for 'tel:+7 (843) 203-92-53'
# https://apply.innopolis.ru/en/bachelorprogram/
# 33876 distinct word(s) so far
# https://apply.innopolis.ru/en/masterprograms/
# 33882 distinct word(s) so far
# https://apply.innopolis.ru/en/international-applicants/
# 33888 distinct word(s) so far
# https://twitter.com/@InnopolisU
# https://apply.innopolis.ru/en/masterprograms/se/
# 33897 distinct word(s) so far
# https://apply.innopolis.ru/en/masterprograms/sne/
# 33900 distinct word(s) so far
# https://apply.innopolis.ru/en/masterprograms/data/
# 33903 distinct word(s) so far
# https://apply.innopolis.ru/en/masterprograms/robotics/
# 33908 distinct word(s) so far
# https://apply.innopolis.ru/en/+7 (843) 203-92-53 (доб. 254)
# https://university.innopolis.ru/about/info/
# https://media.innopolis.university/en/news/?TAGS=*
# 33908 distinct word(s) so far
# https://media.innopolis.university/en/news/?TAGS=Industry
# 33908 distinct word(s) so far
# https://media.innopolis.university/en/news/?TAGS=Research
# 33908 distinct word(s) so far
# https://media.innopolis.university/en/news/?TAGS=Education
# 33908 distinct word(s) so far
# https://media.innopolis.university/en/news/?TAGS=Students life
# 33908 distinct word(s) so far
# https://media.innopolis.university/en/news/?TAGS=Global
# 33908 distinct word(s) so far
# https://media.innopolis.university/en/news/?TAGS=Robotics
# 33908 distinct word(s) so far
# https://media.innopolis.university/en/news/?TAGS=Blockchain
# 33908 distinct word(s) so far
# https://media.innopolis.university/en/news/?TAGS=Cybersecurity
# 33908 distinct word(s) so far
# https://media.innopolis.university/en/news/?PAGEN_2=2
# 33908 distinct word(s) so far
# https://media.innopolis.university/en/news/?PAGEN_2=3
# 33908 distinct word(s) so far
# https://media.innopolis.university/en/news/?PAGEN_2=38
# 33908 distinct word(s) so far
# https://media.innopolis.university/en/news/?PAGEN_2=39
# 33908 distinct word(s) so far
# https://media.innopolis.university/en/events/?date=
# 33908 distinct word(s) so far
# https://media.innopolis.university/en/events/?date=past
# 33908 distinct word(s) so far
# https://media.innopolis.university/en/events/?SECTION_ID=
# 33908 distinct word(s) so far
# http://www.minsvyaz.ru/
# 33908 distinct word(s) so far
# http://www.minsvyaz.ru/en/ministry/common/
# 33926 distinct word(s) so far
# http://www.minsvyaz.ru/en/events/list/
# 33997 distinct word(s) so far
# http://www.minsvyaz.ru/en/activity/
# 33997 distinct word(s) so far
# http://www.minsvyaz.ru/en/documents/
# 33997 distinct word(s) so far
# http://www.minsvyaz.ru/en/contacts/
# 34022 distinct word(s) so far
# http://www.minsvyaz.ru/en/appeals/license/
# 34045 distinct word(s) so far
# http://www.minsvyaz.ru/set_lang/ru/
# 34045 distinct word(s) so far
# http://www.minsvyaz.ru/en/None
# http://www.minsvyaz.ru/en/events/34346/
# 34064 distinct word(s) so far
# http://www.minsvyaz.ru/en/events/34343/
# 34071 distinct word(s) so far
# http://www.minsvyaz.ru/en/events/34340/
# 34076 distinct word(s) so far
# http://www.minsvyaz.ru/en/events/34334/
# 34091 distinct word(s) so far
# http://www.minsvyaz.ru/en/events/34337/
# 34113 distinct word(s) so far
# http://www.minsvyaz.ru/en/ministry/structure/
# 34130 distinct word(s) so far
# http://www.minsvyaz.ru/en/contacts/media/
# 34135 distinct word(s) so far
# https://twitter.com/minsvyaz_news
# https://www.facebook.com/minsvyaz?fref=ts
# 34182 distinct word(s) so far
# https://www.instagram.com/minsvyaz_official
# 34182 distinct word(s) so far
# HTTPSConnectionPool(host='government.ru', port=443): Max retries exceeded with url: /en/news/21075 (Caused by SSLError(SSLError("bad handshake: SysCallError(32, 'EPIPE')")))
# https://t.co/3Qc4MHFr2O
# http://twitter.com/MedvedevRussiaE
# https://twitter.com/telegram:
# https://t.co/69Yhn2MCrK
# 34184 distinct word(s) so far
# http://twitter.com/nnikiforov
# http://twitter.com/@mission_russian
# https://twitter.com/hashtag/Russia
# https://twitter.com/hashtag/Iran
# https://t.co/3WeEJ8C11x
# 34369 distinct word(s) so far
# http://twitter.com/SteppeDispatch
# http://www.minsvyaz.ru/en/appeals/form/
# 34495 distinct word(s) so far
# http://www.minsvyaz.ru/en/contacts/letter/
# 34502 distinct word(s) so far
# http://www.minsvyaz.ru/en/search/
# 34509 distinct word(s) so far
# http://www.minsvyaz.ru/en/subscription/#rss
# 34509 distinct word(s) so far
# http://www.minsvyaz.ru/opendata/
# 34553 distinct word(s) so far
# http://www.minsvyaz.ru/en/subscription/
# 34553 distinct word(s) so far
# http://www.minsvyaz.ru/en/pages/about/
# 34558 distinct word(s) so far
# https://cnt.sputnik.ru/report/894092
# 34558 distinct word(s) so far
# Done
# [('и', 12312), ('в', 10239), ('of', 8268), ('and', 8143), ('the', 8022), ('на', 4800), ('in', 4364), ('с', 3342), ('to', 3323), ('university', 3243), ('по', 2887), ('a', 2620), ('для', 2613), ('for', 2592), ('иннополис', 2561), ('innopolis', 1978), ('it', 1649), ('is', 1465), ('не', 1446), ('мы', 1383)]
